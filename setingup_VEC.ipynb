# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install PyPDF2
# !pip install langchain
# !pip install langchain-community
# !pip install langchain-experimental
# !pip install pypdf
# !pip install sentence-transformers
# !pip install spellchecker
# Out:
# Requirement already satisfied: PyPDF2 in /usr/local/lib/python3.10/dist-packages (3.0.1)
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.3.6)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.10.10)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.14 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.15)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.3.0)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.1.137)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.9.2)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.17.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.14->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.14->langchain) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.14->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.14->langchain) (3.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain) (0.2.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.2.2)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.3.4)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.3.6)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.14 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.3.15)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.137)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.6.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.23.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.6->langchain-community) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.6->langchain-community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.14->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.14->langchain-community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.14->langchain-community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.14->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.6->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.6->langchain-community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community) (0.2.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community) (1.2.2)
# Requirement already satisfied: langchain-experimental in /usr/local/lib/python3.10/dist-packages (0.3.2)
# Requirement already satisfied: langchain-community<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain-experimental) (0.3.4)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from langchain-experimental) (0.3.15)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.0.36)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.10.10)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.6.7)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.4.0)
# Requirement already satisfied: langchain<0.4.0,>=0.3.6 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.6)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.1.137)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.6.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community<0.4.0,>=0.3.0->langchain-experimental) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain-experimental) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain-experimental) (24.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.5.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain-experimental) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.7 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4.0,>=0.3.6->langchain-experimental) (4.12.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (4.0.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.23.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.9.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain-experimental) (3.0.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.6->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.3.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.10.10)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.6->langchain-experimental) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3.0.0,>=2.5.2->langchain-core<0.4.0,>=0.3.6->langchain-experimental) (2.23.4)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (2024.8.30)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.1.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (3.7.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.14.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.0.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp<4.0.0,>=3.8.3->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (0.2.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain-community<0.4.0,>=0.3.0->langchain-experimental) (1.2.2)
# Requirement already satisfied: pypdf in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: typing_extensions>=4.0 in /usr/local/lib/python3.10/dist-packages (from pypdf) (4.12.2)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.66.6)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.5.0+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.24.7)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2024.3.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence-transformers) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (1.26.4)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.19.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2024.8.30)
# Requirement already satisfied: spellchecker in /usr/local/lib/python3.10/dist-packages (0.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spellchecker) (75.1.0)
# Requirement already satisfied: inexactsearch in /usr/local/lib/python3.10/dist-packages (from spellchecker) (1.0.2)
# Requirement already satisfied: soundex>=1.0 in /usr/local/lib/python3.10/dist-packages (from inexactsearch->spellchecker) (1.1.3)
# Requirement already satisfied: silpa-common>=0.3 in /usr/local/lib/python3.10/dist-packages (from inexactsearch->spellchecker) (0.3)

# %%
from transformers import AutoTokenizer
import re
from langchain.document_loaders import PyPDFLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_experimental.text_splitter import SemanticChunker



# Define data paths
DATA_PATH_1 = '/content/drive/MyDrive/UNH_Hackathon/UNH_Hackathon_Data_PDFs/A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'
DATA_PATH_2 = '/content/drive/MyDrive/UNH_Hackathon/UNH_Hackathon_Data_PDFs/Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship.pdf'
DATA_PATH_3 = '/content/drive/MyDrive/UNH_Hackathon/UNH_Hackathon_Data_PDFs/Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'
DATA_PATH_4 = '/content/drive/MyDrive/UNH_Hackathon/UNH_Hackathon_Data_PDFs/US_Mercy.pdf'
DATA_PATH_5 = '/content/drive/MyDrive/UNH_Hackathon/UNH_Hackathon_Data_PDFs/Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'

# Create a list of lists with path and filename
data_paths = [
    [DATA_PATH_1, 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'],
    [DATA_PATH_2, 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'],
    [DATA_PATH_3, 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'],
    [DATA_PATH_4, 'US_Mercy.pdf'],
    [DATA_PATH_5, 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf']
]


combined_chunk_list = []  # List to hold combined chunks
metadata_list = []  # List to hold metadata for combined chunks

# Threshold for max chunk length after combination
MAX_COMBINED_LENGTH = 512

# Initialize the tokenizer for token counting
tokenizer = AutoTokenizer.from_pretrained("sentence-transformers/all-MiniLM-L6-v2")


# Combine related chunks, restarting on new pages
temp_text = ""  # Temporary variable for merging chunks
previous_page = None  # Track the page number of the last chunk
start_page = None  # Track the starting page of the combined chunk


# Initialize embedding model
embed_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

# Enhanced pattern to detect only structured tables without narrative context
table_pattern = re.compile(
    r'(\d+\s*\(.*?\))|'             # Numbers with parentheses, e.g., '10 (some text)'
    r'(\bX\b)|'                     # Standalone "X", e.g., ' X '
    r'((?:\d+\s+){3,})|'            # Three or more consecutive numbers, e.g., '10 20 30'
    r'(.*?\d+%\s*){3,}'             # Three or more percentages, e.g., '20% 30% 40%'
)



# Extract text from each page
for doc in data_paths:

    # Uses langchain's document loader
    loader = PyPDFLoader(doc[0])
    data = loader.load()

    # Initial split so chunk size is more consistent
    size= 512
    overlap = 50
    splitter = RecursiveCharacterTextSplitter(chunk_size=size, chunk_overlap=overlap)
    documents = splitter.split_documents(data)


    # Recreate chunks with semantic chunker
    semantic_chunker = SemanticChunker(embed_model, breakpoint_threshold_type="percentile")
    semantic_chunks = semantic_chunker.split_documents(documents)

    # create metadate

    for chunk in semantic_chunks:
      chunk_text = chunk.page_content
      if not table_pattern.search(chunk_text):
        chunk_text = chunk.page_content.strip()
        current_page = chunk.metadata['page']  # Get the current chunk's page number

        # Calculate token count of the current combined text
        combined_text = temp_text + " " + chunk_text
        combined_tokens = len(tokenizer.tokenize(combined_text))

        # Check if we're on a new page or if adding the chunk exceeds max length
        if previous_page is not None and (current_page != previous_page or combined_tokens > MAX_COMBINED_LENGTH):
            # Save the current combined chunk and its metadata
            combined_chunk_list.append(temp_text.strip())
            metadata_list.append({
                'source': doc[1],
                'page': start_page,
            })

            # Start a new chunk
            temp_text = chunk_text
            start_page = current_page  # Set the starting page for the new chunk
        else:
            # Concatenate the current chunk to temp_text
            temp_text += " " + chunk_text
            if start_page is None:
                start_page = current_page  # Initialize start_page if starting new combined chunk

        previous_page = current_page  # Update the previous_page to the current page

    # Append any remaining text and metadata as the final chunk
    if temp_text:
        combined_chunk_list.append(temp_text.strip())
        metadata_list.append({
            'source': doc[1],
            'page': start_page,
        })
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# <ipython-input-3-edae4169735b>:44: LangChainDeprecationWarning: The class `HuggingFaceEmbeddings` was deprecated in LangChain 0.2.2 and will be removed in 1.0. An updated version of the class exists in the :class:`~langchain-huggingface package and should be used instead. To use it run `pip install -U :class:`~langchain-huggingface` and import as `from :class:`~langchain_huggingface import HuggingFaceEmbeddings``.
#   embed_model = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# Token indices sequence length is longer than the specified maximum sequence length for this model (573 > 512). Running this sequence through the model will result in indexing errors

# %%
from pprint import pprint
pprint(combined_chunk_list)
# Out:
# ['MILITARY MEDICINE, 188, 7/8:e1802, 2023\n'
#  'A Decade of Surgery Aboard the U.S. Naval Ship\n'
#  'COMFORT (T-AH 20)\n'
#  'CDR T amara J. Worlton, MD, FACS*,†; CPT Rathnayaka MKD Gunasingha, MD\n'
#  ' †; \n'
#  'LCDR Rex Atwood, MD†; CDR Mark Johnson, MD, FACS‡; CDR Ian C. Uber, MD§\n'
#  ' \n'
#  'ABSTRACT \n'
#  'Introduction:\n'
#  'The U.S. Naval Ship COMFORT has performed six humanitarian assistance and '
#  'disaster relief mission since 2007. This \n'
#  'paper describes the surgical volume per surgical specialty for five missions '
#  'spanning 19 countries. Materials and Methods:\n'
#  'Raw surgical case logs were analyzed for total case volume, total operating '
#  'days, unanticipated return to operating room, \n'
#  'and percentage of pediatric cases (<18 years old) for each country visited. '
#  'Results:\n'
#  'Total surgical volume for the five missions was 5,142. The countries most '
#  'frequently visited were Columbia and Haiti \n'
#  'with seven and five visits, respectively. General surgery, ophthalmology, '
#  'and plastic surgery have had consistent volume over time. Orthopedic surgery '
#  'volume has steadily decreased with the exception of the 2018 mission. '
#  'Conclusion:\n'
#  'As volume in military treatment facilities declines, alternative sources of '
#  'surgical volume for military surgeons are being \n'
#  'examined. This paper highlights the historical volume which can inform '
#  'future personnel planning requirements of U.S. Naval Ship COMFORT missions. '
#  'With the exception of orthopedic surgery, surgical volume has remained '
#  'consistent over the last decade. For future best practice, historical case '
#  'data should be used to determine staffing needs on hospital \n'
#  'ships and case logs and operating procedures and follow-up protocols should '
#  'be standardized. BACKGROUND\n'
#  'The U.S. Naval Ship (USNS) COMFORT was commissioned \n'
#  'as a hospital ship in 1987. Although hospital ships are primar-\n'
#  'ily intended to serve as a combat support platform, they are \n'
#  'most frequently used in humanitarian assistance and disaster relief.1–3 In '
#  '2007, the U.S. Southern Command introduced \n'
#  ' *Department of Surgery, Uniformed Services University of the Health \n'
#  'Sciences, Bethesda, MD 20889, USA\n'
#  '†Department of Surgery, Walter Reed National Military Medical Center, \n'
#  'Bethesda, MD 20889, USA\n'
#  '‡Department of General Surgery, Navy Medicine Readiness and Training \n'
#  'Command, Portsmouth, V A 23708, USA\n'
#  '§Department of Ophthalmology, Navy Medicine Readiness and Training \n'
#  'Command, Portsmouth, V A 23708, USA',
#  'Command, Portsmouth, V A 23708, USA\n'
#  'The views expressed in this article are those of the authors and do not \n'
#  'necessarily reflect the official policy or position of the Department of '
#  'the \n'
#  'Navy, Department of Defense, or the United States Government. We are mil-\n'
#  'itary service members. This work was prepared as part of our official '
#  'duties. Title 17 U.S.C. 105 provides that “Copyright protection under this '
#  'title is not \n'
#  'available for any work of the United States Government.” Title 17 U.S.C. 101 '
#  'defines a United States Government work as a work prepared by a military \n'
#  'service member or employee of the United States Government as part of that \n'
#  'person’s official duties. The opinions or assertions contained herein are '
#  'the private ones of the \n'
#  'author/speaker and are not to be construed as official or reflecting the '
#  'views of \n'
#  'the Department of Defense, the Uniformed Services University of the Health \n'
#  'Sciences or any other agency of the U.S. Government. '
#  'doi:https://doi.org/10.1093/milmed/usac278 '
#  'doi:https://doi.org/10.1093/milmed/usac278\n'
#  '© The Association of Military Surgeons of the United States \n'
#  '2022. All rights reserved. For permissions, please e-mail: journals. '
#  'permissions@oup.com. Continuing Promise which is a training mission intended '
#  'to \n'
#  'strengthen partnerships and cooperation between the USA and \n'
#  'partner nations (PN) through medical, dental, veterinary, and \n'
#  'other humanitarian assistance activities.4,5\n'
#  'The USNS COMFORT has completed six Continuing The USNS COMFORT has completed '
#  'six Continuing \n'
#  'Promise missions since 2007. 4 Direct patient care is a key \n'
#  'component of the USNS COMFORT mission and is the most \n'
#  'expansive surgical care global health engagement (GHE) in \n'
#  'the Department of Defense (DoD). Publications looking at \n'
#  'comprehensive surgical volume for the 2007, 2015, and 2018 \n'
#  'missions and specialized surgical volume for 2009 and 2011 \n'
#  'have already been published.6–10 We are unaware of any pub- lications that '
#  'have examined overall volume in the context of \n'
#  'previous missions. This paper provides comprehensive sur-\n'
#  'gical case volume over different time frames with different \n'
#  'PNs for numerous USNS COMFORT surgical missions. The \n'
#  'ship has also responded to numerous disasters to include \n'
#  'the 9/11 response in New York City, Hurricane Katrina in \n'
#  'New Orleans, the 2010 earthquake in Haiti, Hurricane Maria \n'
#  'in Puerto Rico, and the COVID-19 response in New York',
#  'City.3,18 The planning and execution of these missions are \n'
#  'very different from the humanitarian assistance missions, and \n'
#  'therefore, are not included in this paper. In the context of decreasing '
#  'surgical volume in military \n'
#  'treatment facilities, alternative methods of increasing individ-\n'
#  'ual surgeon case volume are being examined. 11,12 Surgical \n'
#  'case volume is necessary for combat support readiness. This \n'
#  'paper elucidates trends for each surgical specialty involved in e1802 '
#  'MILITARY MEDICINE , V ol. 188, July/August 2023\n'
#  'Downloaded from '
#  'https://academic.oup.com/milmed/article/188/7-8/e1802/6761490 by Booz & '
#  'Company (UK) Ltd. user on 28 August 2024',
#  'A Decade of Surgery Aboard the USNS COMFORT (T-AH 20)\n'
#  'these expansive missions for the purpose of informing mis-\n'
#  'sion planners of the personnel that are most likely to benefit \n'
#  'from participation in future missions. Additionally, this data provide some '
#  'background to dis-\n'
#  'cuss the impact on PN surgeons and health care systems, \n'
#  'such as loss of certain cases and potential income to those on \n'
#  'the ship, through direct patient care missions. An important \n'
#  'component of DoD GHE is examining the capability and sta- bility of a '
#  'nation’s health infrastructure, and it is imperative \n'
#  'to examine these missions in this context and how partner-\n'
#  'ships can be developed in addition to the surgical readiness\n'
#  'mission.13–15\n'
#  'METHODS\n'
#  'After approval from the Institutional Review Board at Naval \n'
#  'Medical Center Portsmouth, a retrospective review of sur-\n'
#  'gical procedures aboard the USNS COMFORT was con-\n'
#  'ducted. Surgical case logs were available from 2009, 2011, \n'
#  '2015, 2018, and 2019. Additionally, publications pertain- ing to surgical '
#  'cases from Continuing Promise missions \n'
#  'were reviewed. 5–9 The data were independently analyzed \n'
#  'by two authors, TW and KG, to ensure consistent and \n'
#  'accurate counts. Total case volume, total operating days, \n'
#  'number of surgeons participating in the mission, and per-\n'
#  'centage of pediatric (<18 years old) for each PN visited were\n'
#  'recorded. Cases related to multiple specialties, for example, cleft lip, \n'
#  'were counted for the primary surgeon’s specialty. Pediatric cases were '
#  'recorded by patient age and not by specialty as \n'
#  'these cases crossed multiple specialties. Cases were labeled \n'
#  'as the specialty of the surgeon. For example, if an urologist \n'
#  'performed an inguinal hernia repair this would be counted as \n'
#  'a urology case and not a general surgery case. Complications, \n'
#  'including unanticipated return to operating room (OR), were \n'
#  'noted. This paper used the Standards for Reporting Qualitative \n'
#  'Research (SRQR) checklist.16\n'
#  'RESULTS Research (SRQR) checklist.16\n'
#  'RESULTS\n'
#  'Surgical missions took place in 2009, 2011, 2015, 2018, and \n'
#  '2019 with a total of 19 distinct countries visited within the \n'
#  'USSOUTCOM Area of Responsibility (see Table I). Total sur-\n'
#  'gical volume for years with available case logs was 5,142. The \n'
#  'number of operative days per city ranged from 4 to 9 with an \n'
#  'average of 6.3 days. The surgical specialties represented on the USNS COM-\n'
#  'FORT have varied over time with general surgery, orthopedic',
#  'surgery, plastic surgery, oral and maxillofacial surgery, and \n'
#  'Ophthalmology present on every mission (see Table II). The \n'
#  'surgical case logs from 2007 were unobtainable and were not \n'
#  'included in this paper. In a study by Hartgeril et  al, the total \n'
#  '2007 mission surgical volume was 1,163, leading to a total of \n'
#  '6,305 surgeries for all Continuing Promise missions. 6 Surgi-\n'
#  'cal volume for each specialty per mission year is presented \n'
#  'in Table III. Specialty surgical cases were diverse in nature, and the '
#  'single mission with the most cases per specialty was: \n'
#  'general surgery with 92 cases in Panama 2009, ophthalmol-\n'
#  'ogy with 65 cases in Honduras 2018, urology with 26 cases in \n'
#  'Costa Rica in 2011, plastic surgery with 24 cases in Colombia \n'
#  '2019, gynecology with 21 cases in Nicaragua 2009, ortho-\n'
#  'pedic surgery with 18 cases in Dominican Republic 2009, \n'
#  'otolaryngology with 18 cases in Jamaica 2015, and oral and \n'
#  'maxillofacial surgery with 16 cases in Colombia 2009 (see \n'
#  'Table IV). Table IV). There was limited information about non-operative '
#  'com-\n'
#  'plications or follow-up of surgical patients. The case logs \n'
#  'were reviewed for patients with return trips to the OR. OR cases were '
#  'cataract revision ( n = 2), hysterectomy after \n'
#  'dilation and curettage (n = 1), intraocular lens reposition and \n'
#  'wound repair (n = 1), hypotony reversal after cataract (n = 1), \n'
#  'revision inguinal hernia ( n = 1), eye washout after cataract \n'
#  '(n = 1), exploratory laparotomy and bladder laceration repair \n'
#  'after hysterectomy ( n = 1) and after inguinal hernia repair \n'
#  '(n = 1). Some complications did not require a return trip to \n'
#  'the OR, but were recorded. For example, in 2009, a pedi-',
#  'atric patient had a laryngospasm on induction, and the case \n'
#  'was cancelled. Missions within 2015 had the most thorough \n'
#  'documentation and the logs noted the following nonopera-\n'
#  'tive complications; postoperative urinary retention ( n = 7), \n'
#  'unplanned need for blood transfusion (n = 3), hematoma non-\n'
#  'operative (n = 2), monitoring for angioedema ( n = 1), post-\n'
#  'operative ileus (n = 1), unplanned spermatic cord transection \n'
#  '(n = 1), unintentional cystostomy ( n = 1), and reintubation and ICU '
#  'admission ( n = 1). In 2018, there was documen-\n'
#  'tation of admission to ICU for inverted T waves ( n = 1), \n'
#  'surgery aborted (no reason given) and admission to the ICU \n'
#  'for an anesthesia reaction ( n = 1). In 2019, there was an \n'
#  'ICU admission for suspected malignant hyperthermia and \n'
#  'an unanticipated prolonged ICU stay for pediatric airway \n'
#  'monitoring. DISCUSSION\n'
#  'This paper seeks to give the most thorough information from \n'
#  'a decade of humanitarian assistance missions conducted by the USNS COMFORT '
#  'about all surgical specialties from the \n'
#  'available surgical logs. Surgical specialty representation on \n'
#  'the mission should be based on a number of factors, to include \n'
#  'overall mission parameters and limitations on staffing because \n'
#  'of other military requirements. The hospital ship is primarily \n'
#  'intended for combat support; however, this type of deploy-\n'
#  'ment for the hospital ships is rare; the last mission was during \n'
#  'Operation Iraqi Freedom in 2003.2,17 Operation Iraqi Freedom in 2003.2,17\n'
#  'The information presented here should aid logistical plan-\n'
#  'ning for surgical supplies based on the countries on the mis-\n'
#  'sion. General surgery and ophthalmology have consistently \n'
#  'MILITARY MEDICINE, V ol. 188, July/August 2023 e1803\n'
#  'Downloaded from '
#  'https://academic.oup.com/milmed/article/188/7-8/e1802/6761490 by Booz & '
#  'Company (UK) Ltd. user on 28 August 2024',
#  'It is also important to note that some specialties have a low num-\n'
#  'ber of cases while on the mission. This would be an additional \n'
#  'e1804 MILITARY MEDICINE , V ol. 188, July/August 2023\n'
#  'Downloaded from '
#  'https://academic.oup.com/milmed/article/188/7-8/e1802/6761490 by Booz & '
#  'Company (UK) Ltd. user on 28 August 2024',
#  'This \n'
#  'information can also be used to deploy surgeons to countries \n'
#  'as needed as opposed to staying on board the ship through countries with a '
#  'limited surgical need. This type of judicial \n'
#  'manning would increase the individual surgeon’s case vol-\n'
#  'ume as time on the ship without operating would be limited, \n'
#  'and surgeons could continue their military treatment facilities \n'
#  'based practice longer. For example, the orthopedic surgeon \n'
#  'onboard in 2019 completed 22 cases, but spent 5 months away \n'
#  'from their regular surgical practice. Partnerships with non-\n'
#  'governmental organizations and local surgeons in the PN can help filling '
#  'staffing gaps on the ship and can increase capa-\n'
#  'bility and strengthen the relationship with the PN. Patient \n'
#  'screening and surgical follow-up can also be established with \n'
#  'local surgeons that are there for a longer term. Concurrent \n'
#  'use of local hospitals for surgeries would allow for easier \n'
#  'patient follow-up care in addition to the opportunity for all \n'
#  'surgical team members to meet their colleagues and form \n'
#  'relationships. An additional surgical readiness benefit of these missions is '
#  'the opportunity for surgeons to gain diverse experience by \n'
#  'participating in surgeries outside of their primary specialty. As \n'
#  'most cases have more than one attending surgeon operating, \n'
#  'there is the opportunity to learn in a safe, controlled environ-\n'
#  'ment. In 2019, there was a single surgeon for each of the \n'
#  'following specialties: urology, orthopedics, plastic surgery, \n'
#  'and pediatric surgery, therefore, there was ample opportunity \n'
#  'for other specialties to assist. This type of experience could potentially '
#  'be beneficial for surgeons deployed in remote and \n'
#  'austere environments without immediate access to subspe-\n'
#  'cialty surgical care. GHE has been discussed as a potential avenue for '
#  'increas-\n'
#  'ing case volume for military surgeons, which is a key compo-\n'
#  'nent of readiness, but requires an assessment on the potential \n'
#  'for unintended impact on the PN health care system. 19–21 \n'
#  'First, the lack of an organized method of follow-up and report-\n'
#  'ing surgical complications has been commented on in multiple papers.6–10,22 '
#  'Not every complication requires an immediate \n'
#  'unanticipated return to the OR, and so the understanding of \n'
#  'postoperative complications for this mission is extremely lim-\n'
#  'ited. It is unknown what this burden is on the PN after the \n'
#  'hospital ship has left port. As mentioned above, partnerships \n'
#  'with PN hospitals, surgeons, and local non-governmental \n'
#  'organizations could solve the issue of unorganized patient \n'
#  'follow up. Secondly, although every effort is made to have adequate',
#  'pre-mission planning, there are limitations that impact the \n'
#  'surgical mission. For example, in 2019, the pre-deployment \n'
#  'site survey had less than 2 months for planning. 22 Surgical \n'
#  'case recruitment stems from the pre-deployment site sur-\n'
#  'vey communicating the hospital ship capabilities to PN, as \n'
#  'their early involvement can directly impact surgical volume. The inability '
#  'to identify gaps in PN surgical subspecialty \n'
#  'capability, combined with the very short time in country, leads to decreased '
#  'complexity in the recruited surgical cases \n'
#  'and missed opportunity for expertise exchanges, negatively \n'
#  'impacting both the surgical readiness and strengthening of the \n'
#  'PN mission. As an example, there were PN requests in 2019 \n'
#  'for bariatric surgery, cardiothoracic surgery, and transplant \n'
#  'MILITARY MEDICINE, V ol. 188, July/August 2023 e1805\n'
#  'Downloaded from '
#  'https://academic.oup.com/milmed/article/188/7-8/e1802/6761490 by Booz & '
#  'Company (UK) Ltd. user on 28 August 2024',
#  'A Decade of Surgery Aboard the USNS COMFORT (T-AH 20)\n'
#  'surgery that were unable to be met either because of the PN \n'
#  'not knowing it was available until too late to recruit patients \n'
#  '(bariatric surgery) or not identifying early enough to include \n'
#  'these experts in the country specific mission (cardiothoracic \n'
#  'and transplant surgeries). Short-term surgical missions can improve access '
#  'to care, \n'
#  'particularly for complex patients, when there is inclusion of local '
#  'surgeons.23–25 It is difficult to plan for the unintended \n'
#  'consequences of a massive direct patient care mission, where \n'
#  'local provider perspective is desperately needed. This per-\n'
#  'spective includes displacement of local health care providers \n'
#  'as well as long-term complications that may arise from these \n'
#  'types of missions. Inclusion of PN surgeons is a necessary \n'
#  'component of long-term follow up of patients, subject mat-\n'
#  'ter expert exchanges, and avoiding inadvertently negatively impacting the '
#  'local health care system. Also, when PN sur-\n'
#  'geons operate on the ship, they have the opportunity to use \n'
#  'techniques and technology that may not be readily available.26\n'
#  'Planning for surgical missions is extremely complicated \n'
#  'and has to meet the needs of the U.S. Government, the PN gov-\n'
#  'ernment, active duty personnel on the ship, local and active \n'
#  'duty surgeons, PN patients, in addition to many other stake-\n'
#  'holders. Manning requirements of the ship are mission based; however, '
#  'trauma-relevant personnel are relatively inflexible. Although the ship is '
#  'manned to be “trauma-ready,” those \n'
#  'surgeons may never see a trauma while on the ship, and para-\n'
#  'doxically, have decreased readiness for trauma. Solutions may \n'
#  'be sending the trauma and orthopedic surgeons to work with \n'
#  'local surgeons and hospitals that get trauma patients or alter-\n'
#  'ing the manning requirements to shorter deployments so not \n'
#  'to be away from their primary practice. The combatant com- mand, in addition '
#  'to ensuring that relationships with PNs and \n'
#  'increasing security cooperation should consistently include \n'
#  'PN medical staff in the planning process. PN medical staff \n'
#  'would be able to help offload personnel requirements, guar-\n'
#  'antee appropriate follow up for patients, and help with local \n'
#  'logistics. Current needs and data from the PN in addition to \n'
#  'prior surgical case volume can be used further to determine \n'
#  'staffing and logistic requirements. In addition to overall mis-',
#  'sion planning, surgery focused planning is crucial in ensuring \n'
#  'there is a need for a particular surgeon to be on the ship. The \n'
#  'PN is mainly responsible for screening surgical patients and \n'
#  'logistical limitations, such as the length of the planning cycle \n'
#  'and lack of surgeons from either side in the planning process, \n'
#  'limit how effective a mission can be for surgeon readiness. The total case '
#  'volume reported in this paper may be differ-\n'
#  'ent from published papers, which we attribute to our exclusion of endoscopy '
#  'and interventional radiology cases conducted in \n'
#  'the main OR. Additionally, we did not count procedures as \n'
#  'separate if done in the same case. For example, a hydrocelec-\n'
#  'tomy and inguinal hernia repair counted as one case. Another \n'
#  'cause of potential discrepancy is that the case was attributed \n'
#  'to the specialty of the primary surgeon and not based on the \n'
#  'type a case. This was done because readiness is determined by \n'
#  'individual surgeon volume. A limitation with reporting how many surgeons '
#  'participated in missions was the recording of \n'
#  'primary surgeon in the raw case logs. Sometimes a surgi-\n'
#  'cal resident was recorded as primary surgeon, which made it \n'
#  'appear like more surgeons were onboard throughout the mis-\n'
#  'sion. This was addressed by contacting surgeons present on \n'
#  'the mission to verify who was on the mission but is limited by \n'
#  'recall bias. Some specialties switched out surgical teams dur-\n'
#  'ing the mission and attempts were made to ensure recording the total number '
#  'at one time onboard and not the total for the \n'
#  'whole mission. Another limitation is the accuracy of the information. The \n'
#  'case logs from these missions are not part of an electronic \n'
#  'health record nor are they kept in a standardized fashion from \n'
#  'year to year. It is highly recommended that for future mis-\n'
#  'sions, a consistent and thorough surgical log is developed \n'
#  'and maintained. Standard Form 516 is filled out for each \n'
#  'case and maintained in a paper patient chart, but it is recom- mended that '
#  'all this data are included in an electronic record \n'
#  'as well.27 Additionally, it is imperative to use current proce-\n'
#  'dural terminology (CPT) codes. It is also recommended that \n'
#  'demographic information of the patient should be maintained \n'
#  'in the log to attempt contact for distant follow up. Complica-\n'
#  'tions should also be recorded in the log whether or not they \n'
#  'require an unanticipated return to the OR. If shipboard infor-\n'
#  'mation technology systems allow, this should be transferred to a centralized '
#  'registry to be audited to give feedback to mission \n'
#  'commanders.',
#  'Ideally, this information should also be made \n'
#  'available to the PN Ministry of Health. Future research should examine '
#  'specific surgical specialty \n'
#  'case logs using the Knowledge, Skills, and Abilities (KSA) \n'
#  'Clinical Readiness Program to be able to comment on its \n'
#  'impact on individual surgeon readiness. 28 The lack of CPT \n'
#  'codes in current surgical logs makes calculation of KSAs for surgeon '
#  'readiness difficult. It is highly recommended that \n'
#  'CPT codes for all cases are noted in surgical logs henceforth. CONCLUSION\n'
#  'This compilation of USNS COMFORT surgical cases shows \n'
#  'consistent surgical volume for General Surgery, Ophthalmol-\n'
#  'ogy, and Plastic and Reconstructive Surgery over the last \n'
#  'decade. Based on the decreasing surgical volume for Ortho-\n'
#  'pedic Surgery, future mission planners should consider only \n'
#  'deploying an Orthopedic Surgeon to specific countries for pre-identified '
#  'cases. Future direct patient care GHE missions \n'
#  'should incorporate standardized medical records, conscien-\n'
#  'tious patient follow-up and inclusion of PN surgeons and \n'
#  'hospitals. ACKNOWLEDGMENTS\n'
#  'The authors would like to acknowledge Michael Bushey, BSN, RN, CNOR \n'
#  'and Eva Chou, MD, USN, MC. FUNDING\n'
#  'None declared. e1806 MILITARY MEDICINE , V ol. 188, July/August 2023\n'
#  'Downloaded from '
#  'https://academic.oup.com/milmed/article/188/7-8/e1802/6761490 by Booz & '
#  'Company (UK) Ltd. user on 28 August 2024',
#  'A Decade of Surgery Aboard the USNS COMFORT (T-AH 20)\n'
#  'CONFLICT OF INTEREST STATEMENT\n'
#  'None declared. REFERENCES\n'
#  '1. US Navy USNS Comfort (T-AH 20). Available at https://www. '
#  'navysite.de/ships/comfort.htm; accessed September 26, 2022. 2. USNS COMFORT '
#  'History. Available at https://www.msc.usff.navy. mil/Ships/Comfort/History/; '
#  'accessed September 26, 2022. 3. Worlton T, Uber I, Bronaugh S, et  al: USNS '
#  'COMFORT \n'
#  '(T-AH 20) surgical services response to the COVID-19 pan- Faller C. United '
#  'States Southern Command Strategy: Enduring \n'
#  'promise for the Americas. Available at https://www.southcom.mil/\n'
#  'Portals/7/Documents/SOUTHCOM_Strategy_2019.pdf?ver=2019- 05-15-131647-353, '
#  'published May 8, 2019; accessed September 26, \n'
#  '2022. 10.1177/000313481808400842. 16. Policy O of the US of D for DoD '
#  'Instruction 2000.30 Global \n'
#  'Health Engagement (GHE) Activities. Available at https://www. '
#  'esd.whs.mil/Portals/54/Documents/DD/issuances/dodi/200030_dodi\n'
#  '_2017.pdf#:∼:text=DODINSTRUCTION2000.30GLOBALHEALTH\n'
#  'ENGAGEMENT%28GHE%29ACTIVITIES,ofGHEactivitieswithpar\n'
#  'tnernation%28PN%29entities. E87–94. 10.1097/TA.0000000000003054. 20. Charron '
#  'BL, Dengler KL, Nguyen BT, Coggins A, Massengill JC, \n'
#  'Tomkins TJ: Gynecologic SURGRETE, New Horizons Guyana 2019: \n'
#  'an experience of a lifetime for global health engagement and medical \n'
#  'readiness. Mil Med 2020. 10.1093/MILMED/USAA169. 21. Worlton TJ, Waller SG, '
#  'Saint Laurent S, Remick K, Malone DL, Elster \n'
#  'EA: Important and often forgotten aspects of surgical GHE: a response \n'
#  'to “Gynecologic SURGRETE, New Horizons Guyana 2019: an experi-',
#  '25. Al-Hadidi A, Alslaim H, Ghawanmeh M, et al: Short-term surgical \n'
#  'trips: local collaboration and its effects on complications and patient '
#  '2022.',
#  '25. Al-Hadidi A, Alslaim H, Ghawanmeh M, et al: Short-term surgical \n'
#  'trips: local collaboration and its effects on complications and patient '
#  '2022.',
#  'Himmelfarb Health Sciences Library, The George Washington University '
#  'Himmelfarb Health Sciences Library, The George Washington University \n'
#  'Health Sciences Research Commons Health Sciences Research Commons \n'
#  'Global Health Faculty Publications Global Health \n'
#  '12-2013 \n'
#  'Hospital ships adrift? Part 2: The role of U.S. Navy hospital ship Hospital '
#  'ships adrift? Part 2: The role of U.S. Navy hospital ship humanitarian '
#  'assistance missions in building partnerships humanitarian assistance '
#  'missions in building partnerships \n'
#  'Derek J. Licina \n'
#  'George Washington University \n'
#  'Sangeeta Mookherji \n'
#  'George Washington University \n'
#  'Gene Migliaccio \n'
#  'Cheryl Ringer \n'
#  'Follow this and additional works at: '
#  'https://hsrc.himmelfarb.gwu.edu/sphhs_global_facpubs \n'
#  ' Part of the Other Public Health Commons \n'
#  'Recommended Citation Recommended Citation Recommended Citation Recommended '
#  'Citation \n'
#  'Licina, D., Mookherji, S., Migliaccio, G., Ringer, C. (2013). Commons. It '
#  'has been accepted for inclusion in Global Health Faculty Publications by an '
#  'authorized administrator \n'
#  'of Health Sciences Research Commons. For more information, please contact '
#  'hsrc@gwu.edu.',
#  'Hospital Ships Adrift? Part 2: The Role of US\n'
#  'Navy Hospital Ship Humanitarian Assistance\n'
#  'Missions in Building Partnerships\n'
#  'Derek Licina, MPH, DrPH;1 Sangeeta Mookherji, MS, PhD;1 Gene Migliaccio, '
#  'MPH, DrPH;1\n'
#  'Cheryl Ringer, MBA, PhD2\n'
#  '1. Department of Global Health, The\n'
#  'George Washington University,\n'
#  'Washington, DC USA\n'
#  '2. Department of Defense – US Navy,\n'
#  'Bethesda, Maryland USA\n'
#  'Correspondence:\n'
#  'Derek Licina, MPH, DrPH\n'
#  'The George Washington University\n'
#  'Department of Global Health\n'
#  '2175 K Street, NW, Suite 200 2175 K Street, NW, Suite 200\n'
#  'Washington, DC 20037 USA\n'
#  'E-mail: derek.j.licina@us.army.mil\n'
#  'Abstract\n'
#  'Introduction: US Navy hospital ships are used as a foreign policy instrument '
#  'to achieve\n'
#  'various objectives that include building partnerships. Despite substantial '
#  'resource\n'
#  'investment by the Department of Defense (DoD) in these missions, their '
#  'impact is\n'
#  'unclear. The purpose of this study was to understand how and why hospital '
#  'ship missions\n'
#  'inﬂuence partnerships among the different participants. Methods: An embedded '
#  'case study was used and included the hospital ship Mercy’s\n'
#  'mission to Timor-Leste in 2008 and 2010 with four units of analysis: the US '
#  'government,\n'
#  'partner nation, host nation, and nongovernmental organizations. Key '
#  'stakeholders\n'
#  'representing each unit were interviewed using open-ended questions that '
#  'explored the\n'
#  'experiences of each participant and their organization. Findings were '
#  'analyzed using a\n'
#  'priori domains from a proposed partnership theoretical framework. A '
#  'documentary review of key policy, guidance, and planning documents was also '
#  'conducted. Results: Fifteen themes related to how and why hospital ship '
#  'missions inﬂuence\n'
#  'partnerships emerged from the 37 interviews and documentary review. The ﬁve '
#  'most\n'
#  'prominent included: developing relationships, developing new perspectives, '
#  'sharing\n'
#  'resources, understanding partner constraints, and developing credibility. '
#  'Facilitators to\n'
#  'joining the mission included partner nations seeking a regional presence and '
#  'senior executive relationships. Enablers included historical relationships '
#  'and host nation\n'
#  'receptivity. The primary barrier to joining was the military leading the '
#  'mission. Internal\n'
#  'constraints included the short mission duration, participant resentment, and '
#  'lack of\n'
#  'personnel continuity. External constraints included low host nation and '
#  'United States\n'
#  'Agency for International Development (USAID) capacity. Conclusion: The '
#  'research ﬁnds the idea of building partnerships exists among most units',
#  'of analysis. However, the results show a delay in downstream effects of '
#  'generating action\n'
#  'and impact among the participants. Without a common partnership deﬁnition '
#  'and policy,\n'
#  'guidance, and planning documents reinforcingthese constructs, achieving the '
#  'partnership\n'
#  'goal will remain challenging. Efforts should be made to magnify the '
#  'facilitators and enablers\n'
#  'while developing mitigation strategies for the barriers and constraints. '
#  'This is the ﬁrst study to scientiﬁcally assess the partnership impact of '
#  'hospital ship missions and could support the\n'
#  'DoD’s effort to establish, enable, and sustainmeaningful partnerships. '
#  'Application of the\n'
#  'ﬁndings to improve partnerships in contextsbeyond hospital ship missions may '
#  'be warranted\n'
#  'and require further analysis. This unique opportunity could bridge the rift '
#  'with humanitarian\n'
#  'actors and establish, enable, and sustainmeaningful partnerships with the '
#  'DoD. Licina D, Mookherji S, Migliaccio G, Ringer C. and disaster response '
#  'missions from 2004-2012.1 The three most signiﬁcant ﬁndings\n'
#  'were: (1) the dearth of Navy hospital ship empirical studies; (2) the scant '
#  'number of\n'
#  'Conﬂicts of interest and funding:This\n'
#  'research, to include travel to Timor-Leste, was\n'
#  'made possible by a $ 10,000 US Paciﬁc\n'
#  'Command and a $ 3,000 US Army Medical\n'
#  'Department Center and School grant. Keywords: disaster response; hospital '
#  'ships;\n'
#  'humanitarian assistance; partnerships;\n'
#  'qualitative research\n'
#  'Abbreviations: qualitative research\n'
#  'Abbreviations:\n'
#  'DoD: Department of Defense\n'
#  'DoS: Department of State\n'
#  'DRG: Diagnosis Related Groups\n'
#  'HA: humanitarian assistance\n'
#  'HN: host nation government\n'
#  'IRB: Institutional Review Board\n'
#  'MoH: Ministry of Health\n'
#  'NGO: nongovernmental organizations\n'
#  'PN: partner nations/governments\n'
#  'PP08: Paciﬁc Partnership 2008\n'
#  'PP10: Paciﬁc Partnership 2010\n'
#  'RVU: Relative Value Units\n'
#  'USAID: United States Agency for\n'
#  'International Development\n'
#  'USG: United States government\n'
#  'USNS: United States Naval Ship USNS: United States Naval Ship\n'
#  'Received: May 22, 2013\n'
#  'Accepted: August 24, 2013\n'
#  'doi:10.1017/S1049023X13008972\n'
#  'Prehospital and Disaster Medicine Vol. 28, No. 6\n'
#  'ORIGINAL RESEARCH',
#  'sources describing partnership impact; and (3) the complete\n'
#  'absence of diplomatic, development, and host nation primary\n'
#  'author publications related to Navy hospital ship missions. The\n'
#  'systematic literature review supported existing criticism of the\n'
#  'Department of Defense (DoD) need to more effectively measure\n'
#  'humanitarian assistance mission impact. The purpose of Part Two of this '
#  'research study was to\n'
#  'understand how and why US Navy hospital ship humanitarian assistance '
#  'missions inﬂuence partnerships. Perceived advantages\n'
#  'and disadvantages of partneringon a US Navy hospital ship mission\n'
#  'as well as the facilitators and barriers to effective partnership were\n'
#  'explored. The study identiﬁed how participating organizations\n'
#  'changed as a result of the partnership and what impact the\n'
#  'partnership had on each organization. A case study of the hospital\n'
#  'ship Mercy mission to Timor-Leste during Paciﬁc Partnership 2008 The single '
#  'case study across\n'
#  'two time periods provided rich information to assess how\n'
#  'participants change as a result of the partnership and increase the\n'
#  'validity and generalizability of the ﬁndings. Findings of this study\n'
#  'inform a proposed theoretical framework that can be used to\n'
#  'improve future hospital ship partnership impact. Ethical clearance was '
#  'obtained from The George Washington\n'
#  'University and Medical Center Ofﬁce of Human Research and the Timor-Leste '
#  'Ministry of Health Cabinet of Health Research\n'
#  'and Development. Methods\n'
#  'Overview\n'
#  'A qualitative study design was used to ﬁll the literature void of\n'
#  'hospital ship partnership impact. Qualitative study designs are\n'
#  'ideal for research questions that require the understanding of\n'
#  'participants’ views.2 This study used open-ended interviews with\n'
#  'key stakeholders and a review of documentary materials provided\n'
#  'by the study participants as the sources of evidence. Open-ended questions '
#  'were used to collect participant views of the hospital ship\n'
#  'mission and across the major domains of a proposed partnership\n'
#  'theoretical framework. This framework was adapted from research\n'
#  'conducted by Boydell and Rugkasa (2007).3 T h e i rc o n c e p t u a lm o d '
#  'e l\n'
#  'described how partnerships could serve as a mechanism for reducing\n'
#  'inequalities in health and was based on the Realistic Evaluation\n'
#  'approach used in evaluating partnerships.4 Data analysis occurred using a '
#  'sequence of interrelated steps including reading, coding,\n'
#  'displaying, reducing, and interpreting the data.5\n'
#  'Timor-Leste represented a unique case (recent post-conﬂict\n'
#  'nation) among all countries visited by the Mercy during the PP08\n'
#  'and PP10 missions and served as the single case in this study. Embedded '
#  'within this unique single case were multiple\n'
#  'participating organizations that served as the units of analysis.',
#  'The four embedded units were the US government (USG), partner governments '
#  '(PN), host nation government (HN), and\n'
#  'nongovernmental organizations (NGO). These subunits pre-\n'
#  'sented further opportunity for extensive analysis in the single\n'
#  'case.6 This ensured all aspects of the partnership were revealed\n'
#  'and understood both within and across the participating\n'
#  'organizations.7 Collectively, this qualitative study design is\n'
#  'known as an embedded case study design.8\n'
#  'Study Sample\n'
#  'The speciﬁc study target population included personnel from each partner '
#  'organization representing the strategic (policy), operational\n'
#  '(planning), and tactical (implementing) levels. Using purposeful\n'
#  'sampling, one-on-one, open-ended interviews were conducted\n'
#  'with key stakeholders.9 Additional contacts were obtained and\n'
#  'pursued as part of a snowball sampling strategy with the original\n'
#  'key stakeholders. This strategy ensured information-rich partici-\n'
#  'pants were pursued and interviewed until information saturation\n'
#  'was reached. Data Collection was reached. Data Collection\n'
#  'Key stakeholder interviews were conducted in person from July\n'
#  'through December 2012 in Washington, DC and Dili, Timor-\n'
#  'Leste. Interview participants in Timor-Leste were coordinated\n'
#  'with the US Agency for International Development (USAID)\n'
#  'and Ministry of Health (MoH) in Timor-Leste. Telephonic\n'
#  'interviews from Washington, DC also were conducted. Each\n'
#  'interview took approximately one hour to complete. An interview\n'
#  'guide composed of open-ended questions was used to obtain stakeholder '
#  'perspectives. The questions explored the experiences\n'
#  'of each participant and were analyzed using a priori domains in\n'
#  'the proposed partnership theoretical framework. These included the\n'
#  'partnership goals, advantages and disadvantages of the partnership,\n'
#  'facilitators and barriers to joining the partnership, external and\n'
#  'internal constraints to the partnership, organizational change, and\n'
#  'successful partnership attributes. Audio recordings of each interview were '
#  'sent to contract support personnel for transcription. Each\n'
#  'interview transcript was reviewed and crosschecked with ﬁeld notes\n'
#  'to validate transcription accuracy. Validated transcripts were\n'
#  'imported into QSR International NVivo 10.0 software (QSR\n'
#  'International Inc., Burlington, Massachusetts USA) for data\n'
#  'management and analysis. The collection and review of documentary materials '
#  'is a\n'
#  'technique used by researchers to gain a better understanding of the events '
#  'that one was unable to witness. 10 In this study,\n'
#  'planning documents used to shape the PP08 and PP10 mission\n'
#  'directly and indirectly were requested by the principal investigator\n'
#  'upon conclusion of the key stakeholder interviews. The documents\n'
#  'provided historical context and insight into the culture of each\n'
#  'participating organization.',
#  'Furthermore, the information gathered\n'
#  'during the review of documentary materials helped substantiate data\n'
#  'from the key stakeholder interviews. Data Analysis Data Analysis\n'
#  'This study used a data analysis process designed for qualitative\n'
#  'public health studies and included reading, coding, displaying,\n'
#  'reducing, and interpreting the data.5 The themes within the\n'
#  'partnership theoretical framework that correspond to the research\n'
#  'questions served as the a priori codes (eg, barriers, facilitators,\n'
#  'constraints, etc). A codebook was generated and included the\n'
#  'deﬁnitions of a priori codes and any new emerging codes to facilitate coding '
#  'consistency and clarity. All interview transcript\n'
#  'line-by-line coding was conducted using QSR NVivo 10.0\n'
#  'software on a continuous basis. Once all documents were coded, the data was '
#  'displayed by\n'
#  'thematic area using the prescribed codes. Comparison of themes\n'
#  'within and between each unit of analysis led to the development\n'
#  'of theoretical explanations that assisted in validating or rejecting\n'
#  'previous and emerging conclusions.5 After the data was displayed, data '
#  'reduction commenced. Primary and secondary\n'
#  'themes were prioritized and non-essential information excluded\n'
#  'from further interpretation. The ﬁnal step of data interpretation\n'
#  'included the determination of relationships and patterns as well\n'
#  'as more focused explanations of the data’s essential meaning.9\n'
#  'Licina, Mookherji, Migliaccio, et al 593\n'
#  'December 2013 Prehospital and Disaster Medicine',
#  'Results\n'
#  'Study Participants\n'
#  'The key stakeholders for the case study included 37 individuals\n'
#  'representing the US Government, Timor-Leste Government,\n'
#  'Partner Nation Militaries, and NGOs (Table 1). An average\n'
#  'number of 9.3 participants per organization were interviewed\n'
#  'with the highest number of participants from the US Govern-\n'
#  'ment (n 514) while the Timor-Leste Government had the\n'
#  'lowest number of participants (n56). The average age of the\n'
#  'stakeholders was 46 years; the youngest participant was 28 and represented '
#  'the partner nation militaries, and the oldest was 69\n'
#  'and represented the NGOs. Thirty-ﬁve percent (13/37) of the\n'
#  'stakeholders were female. The stakeholders had an average of 10 years of '
#  'experience\n'
#  'conducting humanitarian assistance related work with partner\n'
#  'nation military participants having the least (two years) and\n'
#  'NGOs the most (15 years). Thirty-eight percent (14/37) of\n'
#  'participants had prior experience working on Navy hospital ship missions '
#  'with the lowest reported by partner nation participants\n'
#  '(14%) and the highest by Timor-Leste Government participants\n'
#  '(67%). These results are not surprising since the hospital ship\n'
#  'Mercy visited Timor-Leste on four different missions. Exactly\n'
#  'half of the US Government, Timor-Leste Government, and\n'
#  'NGO participants reported prior experience working with US\n'
#  'Government interagency partners. This too is not surprising since\n'
#  'USAID is a key interagency partner within the USG and works with NGOs to '
#  'implement development programs in foreign\n'
#  'nations such as Timor-Leste. None of the partner nation military\n'
#  'participants reported similar interagency experience. Forty-one\n'
#  'percent (15/37) of the stakeholders reported prior experience\n'
#  'working with other military partner nations, with the partner\n'
#  'nation military participants reporting the highest level of prior\n'
#  'experience at 57% (4/7) and host nation participants reporting\n'
#  'the lowest level of prior experience at 33% (2/6). This ﬁnding reinforces '
#  'the historical willingness of militaries to collaborate\n'
#  'and the more recent evolution of military-to-civilian collaboration. Almost '
#  'two-thirds (23/37) of participants reported prior\n'
#  'experience working with NGOs. Timor-Leste Government\n'
#  'ofﬁcials reported the highest level of NGO working experience\n'
#  'at 83% (5/6) with partner nation military participants the\n'
#  'lowest at 29% (2/7). The high percentage among host nation\n'
#  'participants is expected based on the large role NGOs played in',
#  'supporting the recent post-conﬂict nation. The low percentage\n'
#  'among partner nation military participants might suggest cultural\n'
#  'differences between the units of analysis. In terms of Paciﬁc Partnership '
#  'hospital ship missions, 32%\n'
#  '(12/37) of the stakeholders participated in both PP08 and PP10. Sixteen '
#  'percent (6/37) took part in only PP08 and 43% (16/27)\n'
#  'only PP10. Overall, a similar number of participants representing\n'
#  'the strategic, operational, and tactical levels of involvement 6',
#  'and 30% (11/37) at the tactical levels. Strategic level participants\n'
#  'varied across units of analysis with Timor-Leste Government\n'
#  'ofﬁcials having the highest at 67% (4/6) and NGOs the lowest at\n'
#  '10% (1/10). Operational level involvement was highest among US\n'
#  'Government participants at 50% (7/14) and lowest among partner\n'
#  'nation military participants at 14% (1/7). Tactical level involvement\n'
#  'was highest among partner nation military participants at 71% (5/7) with '
#  'none (0/6) of the Timor-Leste Government participants\n'
#  'working at this level duringt h eh o s p i t a ls h i pm i s s i o n s . '
#  'Perceived Mission Goal\n'
#  'As described in Part One of this research, the secondary mission\n'
#  'of the Navy hospital ship is to provide humanitarian assistance. The US '
#  'Paciﬁc Command exercises this task through the\n'
#  'biennial Paciﬁc Partnership mission. One of the stated goals of\n'
#  'the Paciﬁc Partnership mission is to build regional partnerships. The '
#  'results of this study suggest the units of analysis perceived\n'
#  'the goals of the mission and the ability to achieve them\n'
#  'differently. United States Government and NGO participants\n'
#  'identiﬁed building partnerships, providing a training opportunity,\n'
#  'and rendering humanitarian assistance as the three goals of the\n'
#  'mission. Opinions were mixed as to whether the goals were\n'
#  'achieved. Partner nation participants mentioned partnerships and\n'
#  'rendering humanitarian assistance as the two goals with predominantly '
#  'positive opinions of achievement. The host nation\n'
#  'participants identiﬁed rendering humanitarian assistance as the\n'
#  'only goal and all stated it was achieved. Partnership Deﬁnition\n'
#  'With a better understanding of how each unit of analysis deﬁnes\n'
#  'the hospital ship mission goals, which included partnership, there\n'
#  'was a need to understand how different participants deﬁne\n'
#  '‘‘partnership.’’ Two additional questions were asked of the key\n'
#  'stakeholders and included deﬁning partnership in their own terms and the '
#  'ability of the hospital ship partnership to achieve\n'
#  'their stated deﬁnition. An overarching theme of ‘‘two separate\n'
#  'entities working towards a mutual goal’’ was prevalent among US\n'
#  'Government participants with mixed opinions in terms of the\n'
#  'mission achieving this deﬁnition. Many partner nation military\n'
#  'participants used the term equity to deﬁne partnership and they\n'
#  'too expressed mixed opinions of the mission achieving their\n'
#  'deﬁnition. Host nation participants used terms such as mutual understanding, '
#  'collaboration, and commitment to deﬁne partner-\n'
#  'ship and almost all felt their deﬁnition was achieved.',
#  '‘‘Working\n'
#  'together as a team’’ was a recurring theme when NGOs deﬁned\n'
#  'partnership and like two other units of analysis, their opinions\n'
#  'about achievement were mixed. Partnership Themes\n'
#  'In order to understand ‘‘how’’ and ‘‘why’’ Navy hospital ship\n'
#  'missions inﬂuence partnerships, the 15 themes emerging from\n'
#  'the key stakeholder interviews were linked to the partnership theoretical '
#  'framework (Figure 1). Overall, the results suggest\n'
#  'hospital ship missions increase connections, facilitate learning,\n'
#  'and generate actions among participating organizations that\n'
#  'produce impacts at both the individual and overall partnership\n'
#  'level. Increasing connections through the partnership assists in\n'
#  'opening a dialogue and developing trust, relationships, and\n'
#  'credibility among the partners.The theme developing relationships\n'
#  'was mentioned by all participants and had the highest number of references '
#  'in the coded transcripts. Opening a dialogue and\n'
#  'developing credibility were themes mentioned by more than two-\n'
#  'thirds of participants. Developing trust was mentioned by 57% of\n'
#  'participants. Based on the theoretical framework that depicts\n'
#  'increasing connections as the ﬁrst step in the partnership process,\n'
#  'having a high number of references to these supporting themes\n'
#  'ﬁts conceptually. The study ﬁndings also suggest the partners learn during '
#  'the hospital ship mission and develop new perspectives, gain a better\n'
#  'understanding of partner constraints and agendas, and under-\n'
#  'stand the needs of host nation. Three of the four themes were\n'
#  'mentioned by more than two-thirds of participants and developing\n'
#  'new perspectives was the second most cited theme. These ﬁndings\n'
#  'also conceptually support that learning occurs after connections\n'
#  'are made among the participants while acknowledging it is an\n'
#  'iterative process. iterative process. The mission also facilitates action '
#  'among partners that results\n'
#  'in the sharing of resources, innovation in how the partnership is\n'
#  'fostered, and the ability of partner organizations to achieve their\n'
#  'parent organizations objectives. Sharing resources featured in\n'
#  'more than two-thirds of the interviews while the other two\n'
#  'themes were mentioned by less than two-thirds. This ﬁnding\n'
#  'suggests the downstream effects of the partnership as depicted in the '
#  'theoretical framework are not fully realized among the\n'
#  'participants. This shortfall wasreinforced by lower response rates to\n'
#  'impact related themes. Increased visibility, the sharing of leadership,\n'
# ...
#  'America’s ability to\n'
#  'project its military power for the past six decades has been its almost '
#  'complete control over \n'
#  'global commons,” wrote U.S. Joint Forces Command in a 2010 strategy document '
#  '[PDF]. What is the navy’s role? What is the navy’s role? The roles that a '
#  'navy serves depend on its capabilities. The United States is one of only a\n'
#  'handful of countries that have a so-called blue-water navy, which can '
#  'operate across the ope\n'
#  'ocean. Others, constrained by geography or resources, can only maintain '
#  'fleets for coastal\n'
#  'regions (green-water) or for rivers and estuaries (brown-water). The navy’s '
#  'power is rooted in its capacity to use or threaten force, but it also has '
#  'significant diplomatic and constabulary functions. In fulfilling these, the '
#  'U.S. Navy regularly deploys wi\n'
#  'the Marine Corps, an amphibious assault force, and the Coast Guard, which '
#  'enforces maritim\n'
#  'law and conducts search and rescue operations, among other functions. These '
#  'three naval services have several interrelated capabilities that they say '
#  'constitute U.S. power [PDF]:\n'
#  '9/11/24, 8:39 AM Sea Power: The U.S. Navy and Foreign Policy | Council on '
#  'Foreign Relations '
#  'https://www.cfr.org/backgrounder/sea-power-us-navy-and-foreign-policy 2/11',
#  'Forward presence. The navy deploys to various regions where the United '
#  'States has a strategi\n'
#  'interest. This demonstrates a persistent, but not permanent, U.S. '
#  'commitment. Deterrence. It discourages adversaries from acting against the '
#  'United States and its allies and\n'
#  'partners. For example, U.S. Navy ballistic-missile submarines serve as a leg '
#  'of the nuclear tria\n'
#  'particularly valued for their ability to hide and stay a credible threat '
#  'during a potential nucl\n'
#  'conflict. conflict. Sea control. It exercises control over the sea, at least '
#  'in certain areas for certain lengths of tim\n'
#  'Sea control provides a freedom of action that is required for the pursuit of '
#  'other objectives,\n'
#  'such as shipping protection, military sealift—which includes using cargo '
#  'ships to deploy\n'
#  'military assets—and blockades. Power projection. It can threaten or direct '
#  'strikes—from ballistic-missile attacks to amphibiou\n'
#  'assaults—against targets ashore for sustained periods. Maritime security. It '
#  'protects seaborne commerce—some 90 percent of global trade travels by\n'
#  'ship—and generally maintains order at sea. Operations include counterpiracy, '
#  'drug interdict\n'
#  'environmental protection, and other law enforcement measures. Humanitarian '
#  'aid. It responds to natural and man-made disasters with medical, food, and\n'
#  'logistical and security assistance. For example, the U.S. military '
#  'constructed a large pier sever miles off the shore of the Gaza Strip to '
#  'allow cargo ships to offload humanitarian aid shipme\n'
#  'for the enclave. How is the navy used for diplomacy? Maritime powers, '
#  'including the United States, have long used navies to influence the behavi\n'
#  'of allies and adversaries during times of peace. These types of naval '
#  'operations may be intended to support, reassure, deter, or threaten\n'
#  'different actors. Some experts have used the term “gunboat diplomacy” to '
#  'refer to the more coercive use of navies; other analysts have characterized '
#  'the political use of naval power as\n'
#  '“armed suasion.”  \n'
#  'Operations the navy employs for diplomatic effect include:\n'
#  '9/11/24, 8:39 AM Sea Power: The U.S. Navy and Foreign Policy | Council on '
#  'Foreign Relations\n'
#  'https://www.cfr.org/backgrounder/sea-power-us-navy-and-foreign-policy 3/11',
#  'Port calls. For instance, the USS Carl Vinson sailed into Da Nang, Vietnam, '
#  'in 2018 in a signal\n'
#  'China that U.S.-Vietnam ties were warming. It was the first U.S. carrier to '
#  'visit Vietnam since\n'
#  'the United States warred with Communist forces there decades ago; the two '
#  'governments\n'
#  'officially upgraded bilateral ties in 2023. Transits. The USS John Finn '
#  'passed through the Strait of Taiwan in January 2024 following\n'
#  'Taiwanese presidential and parliamentary elections to demonstrate the '
#  '“United States’ commitment to upholding freedom of navigation for all '
#  'nations as a principle,” according to \n'
#  'statement from the fleet’s commander. Freedom of navigation operations. The '
#  'navy regularly conducts such operations, also known a\n'
#  'FONOPs [PDF], to challenge what it sees as excessive maritime claims by '
#  'other states. In fisc\n'
#  'year 2022, the U.S. military challenged [PDF] more than a dozen claimants, '
#  'including China,\n'
#  'Iran, and Russia. Iran, and Russia. Combat capability demonstrations. In '
#  'January 2024, the navy kicked off Steadfast Defender 20\n'
#  'the largest military exercise conducted by the North Atlantic Treaty '
#  'Organization (NATO) in\n'
#  'decades. The six-month-long operation intends to showcase the alliance’s '
#  'ability to move\n'
#  'reinforcements across the Atlantic to support allies in Europe, if they were '
#  'to come under\n'
#  'attack. Force-level changes. Since Russia invaded Ukraine in 2022, NATO '
#  'navies have significantly increased their presence in the Black Sea, sending '
#  'additional ships and troops to the area in\n'
#  'response to Russian operations there. Fleet architecture changes. In 2018, '
#  'the U.S. Navy reestablished its Second Fleet in the Atlanti\n'
#  'recognition of a return to “an era of great power competition.” The navy has '
#  'since committed\n'
#  'a fleet modernization plan [PDF] that increases the fleet size 5 percent by '
#  '2045, replacing ol\n'
#  'units with next-generation unmanned warships and submarines. More broadly, '
#  'navies can exert influence by their mere presence and normal operations. '
#  'For\n'
#  'instance, the navy is a cornerstone of U.S. military alliances with '
#  'far-flung states such as Japa\n'
#  'and the Philippines. 9/11/24, 8:39 AM Sea Power: The U.S. Navy and Foreign '
#  'Policy | Council on Foreign Relations\n'
#  'https://www.cfr.org/backgrounder/sea-power-us-navy-and-foreign-policy 4/11',
#  'Where is the U.S. Navy deployed? The navy has seven fleets covering '
#  'different parts of the world, and it maintains more than a\n'
#  'dozen permanent installations outside the contiguous United States, with '
#  'multiple locations\n'
#  'Italy and Japan. How big is the navy? With around 290 ships, the U.S. Navy '
#  'is not the largest in the world, but it’s the most powerfu\n'
#  'The United States has eleven aircraft carriers, the largest military vessels '
#  'in the world, while rivals China and Russia have three and one, '
#  'respectively. However, such numerical compariso\n'
#  'are of limited value, and defense analysts caution that the yardstick should '
#  'be whether the n\n'
#  'as well as other services, are equipped to fulfill the country’s security '
#  'and foreign policy\n'
#  'objectives. 9/11/24, 8:39 AM Sea Power: The U.S. Navy and Foreign Policy | '
#  'Council on Foreign Relations\n'
#  'https://www.cfr.org/backgrounder/sea-power-us-navy-and-foreign-policy 5/11',
#  'A rationale for U.S. forces in recent decades has been defending against the '
#  'rise of adversarie\n'
#  'that could deny the United States access to important allies and markets in '
#  'Asia and Europe. “The traditional U.S. goal of preventing the emergence of a '
#  'regional hegemon in one part of\n'
#  'Eurasia or another has been a major reason why the U.S. military is '
#  'structured with force\n'
#  'elements that enable it to cross broad expanses of ocean and air space and '
#  'then conduct sustained, large-scale military operations upon arrival,” says '
#  'a 2024 report [PDF] by the\n'
#  '9/11/24, 8:39 AM Sea Power: The U.S. Navy and Foreign Policy | Council on '
#  'Foreign Relations\n'
#  'https://www.cfr.org/backgrounder/sea-power-us-navy-and-foreign-policy 6/11',
#  'Congressional Research Service. In its latest National Security Strategy '
#  '[PDF], President Joe\n'
#  'Biden’s administration listed outcompeting China, constraining Russia, and '
#  'reigning in weap\n'
#  'proliferation in Iran and North Korea as the United States’ top global '
#  'priorities. As of mid-2023, the navy’s goal is to build a fleet of 381 '
#  'manned ships, including 31 larger\n'
#  'amphibious ships, which it projects to meet in the 2030s. Additionally, the '
#  'navy plans to add unmanned vessels by 2045 as part of its goal of creating a '
#  '“hybrid force” that operates above\n'
#  'and below the waterline, then Chief of Naval Operations Admiral Michael '
#  'Gilday said in 202\n'
#  '[PDF]. Who leads the navy? The navy bureaucracy is led by a civilian, the '
#  'secretary of the navy, and a senior military offi\n'
#  'the chief of naval operations (CNO). The Marine Corps also falls under the '
#  'Department of th\n'
#  'Navy but has its own senior officer, the commandant of the Marine Corps. '
#  'Both the CNO and the commandant serve alongside the heads of the air force, '
#  'army, and National Guard as\n'
#  'members of the Joint Chiefs of Staff, a group that advises the president and '
#  'secretary of defe\n'
#  'on military matters. The chiefs, however, do not have operational command '
#  'over their services. The chain of\n'
#  'command runs from the president to the secretary of defense to the combatant '
#  'commanders\n'
#  'with the chairman of the Joint Chiefs of Staff serving as a conduit. There '
#  'are eleven combata commands—seven geographic and four functional—all led by '
#  'four-star officers. Some\n'
#  'commands, such as the Indo-Pacific Command (formerly Pacific Command), have '
#  'been\n'
#  'dominated by one service—in this case, the navy. The coast guard is a '
#  'military service but not part of the navy, although it often partners close\n'
#  'with it in situations that have a constabulary component, such as '
#  'international sanctions\n'
#  'enforcement. For instance, the coast guard has conducted high-profile '
#  'operations with the na in the Asia-Pacific region, such as stopping illegal '
#  'oil and coal shipments that violated UN\n'
#  'sanctions on North Korea. It is a component of the Department of Homeland '
#  'Security but ca\n'
#  'operate as an arm of the navy during wartime. 9/11/24, 8:39 AM Sea Power: '
#  'The U.S. Navy and Foreign Policy | Council on Foreign Relations\n'
#  'https://www.cfr.org/backgrounder/sea-power-us-navy-and-foreign-policy 7/11',
#  'How does the navy deploy? The navy deploys depending on national priorities '
#  'and the mission at hand. Perhaps the mos\n'
#  'well-known formation is the carrier strike group, centered around a '
#  'nuclear-powered aircraft\n'
#  'carrier and its air wing of dozens of warplanes. Providing protection and '
#  'other support for th\n'
#  'group are, generally, a guided-missile cruiser, several guided-missile '
#  'destroyers, an attack\n'
#  'submarine, and a supply ship. More than seven thousand sailors and Marines '
#  'serve each grou As a recent example, the Biden administration deployed the '
#  'USS General R. Ford and its strik\n'
#  'group to the eastern Mediterranean Sea as a show of support for Israel '
#  'following the Octobe\n'
#  '2023, attack by Palestinian militant group Hamas. At any one time, the navy '
#  'has two to thre\n'
#  'carrier groups underway, with the remaining groups cycling through '
#  'maintenance and traini\n'
#  '9/11/24, 8:39 AM Sea Power: The U.S. Navy and Foreign Policy | Council on '
#  'Foreign Relations '
#  'https://www.cfr.org/backgrounder/sea-power-us-navy-and-foreign-policy 8/11',
#  'Another common formation is the amphibious ready group, organized around an '
#  'assault ship\n'
#  'and a marine expeditionary unit, and accompanied by a transport dock ship '
#  'and a dock-land\n'
#  'ship. Carrying a full complement of attack planes and helicopters, flattop '
#  'assault ships such a\n'
#  '9/11/24, 8:39 AM Sea Power: The U.S. Navy and Foreign Policy | Council on '
#  'Foreign Relations\n'
#  'https://www.cfr.org/backgrounder/sea-power-us-navy-and-foreign-policy 9/11',
#  'the USS Wasp and Kearsarge could easily be mistaken for aircraft carriers '
#  'though they are no\n'
#  'classified as such. The navy also has two to three of these groups underway '
#  'at any time. What challenges is the navy facing? The navy faces headwinds as '
#  'it plots its course for the next several decades. Leaders are\n'
#  'particularly watchful of the western Pacific, where the navy is jockeying '
#  'with China for\n'
#  'influence. The United States has long dominated the region’s vast waters, '
#  'but China is pushin hard to gain sway over many of the small island '
#  'countries with development loans and other\n'
#  'inducements. The sparsely populated islands are prized not for their '
#  'commercial potential bu\n'
#  'for their strategic value, analysts say. “This is a pre-conflict type of '
#  'shadow game, a geopolitical non-war version of island-hopping\n'
#  'The Pacific has become strategic again for the first time since World War '
#  'II,” international\n'
#  'security expert Euan Graham told the Financial Times in 2019. The rivalry '
#  'could intensify as China modernizes its navy [PDF], building new aircraft '
#  'carriers, submarines, and frigates. A\n'
#  '2022 security cooperation deal between China and the Solomon Islands '
#  'heightened these\n'
#  'concerns. Meanwhile, China and many other coastal states are asserting '
#  'controversial maritime rights—\n'
#  'such as requiring foreign ships to notify them before sailing through their '
#  'territorial waters—\n'
#  'that if left unchecked could erode the navy’s access. China is also making '
#  'increasingly expans territorial claims and building artificial islands in '
#  'the South China Sea, clashing with\n'
#  'neighboring states that have competing claims, such as the Philippines. '
#  'Defense experts also cite the challenge posed by proliferation of '
#  'anti-access and area denial\n'
#  'capabilities. These weapons, known as A2/AD, are intended to push naval '
#  'adversaries farther\n'
#  'out to sea or to keep them in port. One of the most talked about of these '
#  'threats is the hypersonic anti-ship missile. Russia reportedly fired a '
#  'hypersonic missile in a February 2024\n'
#  'attack on Kyiv, Ukraine, marking the first time this advanced weapon has '
#  'been used in battle\n'
#  'Some naval experts believe these looming threats will usher in a new era of '
#  'naval warfare in\n'
#  'which the aircraft carrier will have no place. The U.S. carrier and '
#  'amphibious fleet “both sha\n'
#  '9/11/24, 8:39 AM Sea Power: The U.S. Navy and Foreign Policy | Council on '
#  'Foreign Relations '
#  'https://www.cfr.org/backgrounder/sea-power-us-navy-and-foreign-policy 10/11',
#  'critically important place in the overall fleet architecture—they are both '
#  'unaffordable\n'
#  'anachronisms of a bygone era,” writes Noel Williams, a naval expert and '
#  'retired Marine offic\n'
#  'for War on the Rocks in 2019. Others say the carrier will likely adapt and '
#  'sail on. “Future carriers may have different design\n'
#  'capabilities, and even names, but the U.S. government’s need to project '
#  'power from the sea w\n'
#  'not change,” says U.S. Navy Captain Kevin Brand, a former CFR military '
#  'fellow. Some claim that the biggest long-term threat to the navy, and to the '
#  'U.S. military generally, i\n'
#  'not foreign but domestic: a shrinking budget. Economists expect the '
#  'challenge to grow as the\n'
#  'U.S. population ages and the country spends more on health care, social '
#  'security, and interes\n'
#  'on the national debt, which is on course to roughly double to around 190 '
#  'percent of gross\n'
#  'domestic product (GDP) over the next thirty years. For media inquiries on '
#  'this topic, please reach out to communications@cfr.org. Noah Berman, Diana '
#  'Roy, and Rhea Basarkar contributed to this report. Will Merrow created the '
#  'graphics. Creative Commons: Some rights reserved. 9/11/24, 8:39 AM Sea '
#  'Power: The U.S. Navy and Foreign Policy | Council on Foreign Relations\n'
#  'https://www.cfr.org/backgrounder/sea-power-us-navy-and-foreign-policy 11/11']

# %%
from pprint import pprint
pprint(metadata_list)
# Out:
# [{'page': 0, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 0, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 0, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 1, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 1, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 1, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 2, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 3, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 3, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 4, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 4, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 4, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 5, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 5, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
#  {'page': 5,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 0,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 1,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 1,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 2,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 2,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 2,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 3,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 3,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 4,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 4,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 4,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 5,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 5,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 6,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 7,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 8,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 9,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 9,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 10,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 10,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 10,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 11,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 11,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 11,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 12,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 12,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 12,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 13,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 13,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 13,
#   'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
#  {'page': 13,
#   'source': 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'},
#  {'page': 0,
#   'source': 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'},
#  {'page': 1,
#   'source': 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'},
#  {'page': 2,
#   'source': 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'},
#  {'page': 3,
#   'source': 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'},
#  {'page': 4,
#   'source': 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'},
#  {'page': 5,
#   'source': 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'},
#  {'page': 6,
#   'source': 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'},
#  {'page': 7,
#   'source': 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'},
#  {'page': 8,
#   'source': 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'},
#  {'page': 9,
#   'source': 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'},
#  {'page': 10,
#   'source': 'Sea_Power_The_US_Navy_and_Foreign_Policy_Council_on_Foreign_Relations.pdf'},
#  {'page': 10, 'source': 'US_Mercy.pdf'},
#  {'page': 0, 'source': 'US_Mercy.pdf'},
#  {'page': 0, 'source': 'US_Mercy.pdf'},
#  {'page': 1, 'source': 'US_Mercy.pdf'},
#  {'page': 2, 'source': 'US_Mercy.pdf'},
#  {'page': 2, 'source': 'US_Mercy.pdf'},
#  {'page': 3, 'source': 'US_Mercy.pdf'},
#  {'page': 3, 'source': 'US_Mercy.pdf'},
#  {'page': 3, 'source': 'US_Mercy.pdf'},
#  {'page': 4, 'source': 'US_Mercy.pdf'},
#  {'page': 4, 'source': 'US_Mercy.pdf'},
#  {'page': 5, 'source': 'US_Mercy.pdf'},
#  {'page': 5,
#   'source': 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf'},
#  {'page': 0,
#   'source': 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf'},
#  {'page': 1,
#   'source': 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf'},
#  {'page': 2,
#   'source': 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf'},
#  {'page': 3,
#   'source': 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf'},
#  {'page': 4,
#   'source': 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf'},
#  {'page': 5,
#   'source': 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf'},
#  {'page': 6,
#   'source': 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf'},
#  {'page': 7,
#   'source': 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf'},
#  {'page': 8,
#   'source': 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf'},
#  {'page': 9,
#   'source': 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf'},
#  {'page': 10,
#   'source': 'US_Navy_Ship_Based_Disaster_Response_Lessons_Learned_PMC.pdf'}]

# %% [markdown]
# Below is the manual inserting of latex version of graphs as chuncks into chunk list and corresponding metadata

# %%
import json

# Load the JSON data
file_path = '/content/drive/MyDrive/UNH_Hackathon/merged_data.json'  # Update with your file path
with open(file_path, 'r') as file:
    data = json.load(file)

# Extract LaTeX content from category_id 5 items with no timeout or timeout = false
latex_content = []

for entry in data:
    for item in entry.get("layout_dets", []):
        if item.get("category_id") == 5:
            # Check if "timeout" is either not present or explicitly false
            if not item.get("timeout", False):  # if timeout is False or missing
                latex_code = item.get("latex", "No LaTeX Content")
                latex_content.append(latex_code)



# List of strings to prepend
prefixes = [
    "Total Volume per Specialty per Year : ",
    "Number of Surgeons by Specialty on Each Mission Year (Estimated) : ",
    "Number of Cases per Country : ",
    "Partnership Themes Listed by Frequency Within and Between Units of Analysis : ",
    "Documentary Partnership Themes Matching Case Study : ",
    "Recent missions of the USNS Mercy (3) : "
]






# Prepend each prefix to the corresponding latex_content string
for i in range(len(prefixes)):
    latex_content[i] = prefixes[i] + " " + latex_content[i]

# Print the updated latex_content to see the result
for content in latex_content:
    print(content)

# Append the contents of prefixes_metadata to metadata_list
combined_chunk_list.extend(latex_content)

prefixes_metadata = [
    {'page': 2, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
    {'page': 2, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
    {'page': 3, 'source': 'A_Decade_of_Surgery_Aboard_the_US_COMFORT.pdf'},
    {'page': 6, 'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
    {'page': 9, 'source': 'Hospital_ships_adrift_Part2_The_role_of_US_Navy_hospital_ship'},
    {'page': 2, 'source': 'US_Mercy.pdf'}
]

# Append the contents of prefixes_metadata to metadata_list
metadata_list.extend(prefixes_metadata)
# Out:
# Total Volume per Specialty per Year :  \begin{tabular}{|>{\hspace{0.5cm}}m{6cm} >{\hspace{0.5cm}}m{2.5cm} >{\hspace{0.5cm}}m{2.5cm} >{\hspace{0.5cm}}m{2.5cm} >{\hspace{0.5cm}}m{1.5cm} >{\hspace{0.5cm}}m{1.5cm}|}\noalign{\smallskip}\noalign{\smallskip}\hline \hline \noalign{\smallskip}\multicolumn{6}{|c|}{} \\[-0.5ex] & 2009 & 2011 & 2015 & 2018 & 2019 \\[0.5ex]\hline \noalign{\smallskip}\textit{Operating days} & 47 & 71 & 84 & 29 & 69 \\\textit{Total mission time Speciallies} & 4\,months & S\,months & 6\,months & 3\,months & S\,months \\General surgery & 506 & 259 & 435 & 265 & 462 \\Gynecology & 115 & 63 & 122 & 0 & 0 \\Ophthalmology & 199 & 312 & 201 & 211 & 412 \\O偏ryngology & SS & 98 & 78 & 0 & 0 \\Oral maxillofacial surgery & 49 & 68 & 75 & 38 & 12 \\Orthopedic surgery & 81 & 94 & 98 & 29 & 22 \\Plastic surgery & 74 & 117 & 129 & 54 & 143 \\Urology & 59 & 100 & 56 & 0 & 51 \\Total & 1,138 & 1,111 & 1,194 & 597 & 1,102 \\\textit{Return to operating room rate} & 0.33\% & 0.18\% & 0.41\% & 0.17\% & 0.74\% \\\% Pediatric cases (age $<$18\,years old)\textsuperscript{a} & 29.6\% & 23.7\% & 19.7\% & 22.6\% & 16.1\% \\[0.5ex]\hline \end{tabular}
# Number of Surgeons by Specialty on Each Mission Year (Estimated) :  \begin{tabular}{|lcccccc|}\hline \hline \thead{} & \thead{2009} & \thead{2011} & \thead{2015} & \thead{2018} & \thead{2019} & \thead{Total (by specialty)}\\\hline \thead{General surgeons} & \thead{6} & \thead{2} & \thead{4} & \thead{4} & \thead{3} & \thead{19}\\\thead{Gynecologists} & \thead{2} & \thead{1} & \thead{2} & \thead{0} & \thead{0} & \thead{10}\\\thead{Ophthalmologists} & \thead{3} & \thead{2} & \thead{1} & \thead{3} & \thead{3} & \thead{12}\\\thead{Oral maxillofacial surgeons} & \thead{1} & \thead{1} & \thead{1} & \thead{2} & \thead{2} & \thead{7}\\\thead{Orthopedic surgeons} & \thead{2} & \thead{2} & \thead{2} & \thead{1} & \thead{1} & \thead{8}\\\thead{Otorminolaryngologists} & \thead{1} & \thead{3} & \thead{1} & \thead{0} & \thead{0} & \thead{5}\\\thead{Pediatric surgeons} & \thead{1} & \thead{1} & \thead{1} & \thead{1} & \thead{1} & \thead{5}\\\thead{Politics and reconstructive surgeons} & \thead{1} & \thead{1} & \thead{1} & \thead{1} & \thead{1} & \thead{5}\\\thead{Urologists} & \thead{2} & \thead{1} & \thead{1} & \thead{0} & \thead{1} & \thead{5}\\\thead{Total (by year)} & \thead{19} & \thead{14} & \thead{14} & \thead{12} & \thead{12} & \\\hline \end{tabular}
# Number of Cases per Country :  \begin{tabular}{|>{\hspace{0.5cm}}m{5cm} >{\hspace{0.5cm}}m{2.5cm} >{\hspace{0.5cm}}m{2.5cm} >{\hspace{0.5cm}}m{2.5cm} >{\hspace{0.5cm}}m{2.5cm} >{\hspace{0.5cm}}m{1.5cm}|}\hline \hline \multicolumn{6}{|c|}{\thead{Year (number of cases)}} \\\cline{2-6}\multicolumn{1}{|l}{Country} & 2009 & 2011 & 2015 & 2018 & 2019 \\\hline \thead{Anigua \\ Belize} & & & X\,(98) & X\,(116) & \\\thead{Columbia \\ Costa Rica} & X\,(205) & X\,(129) & X\,(106) & X\,(137) & X\,(119) \\\thead{Dominica} & & & X\,(120) & & \\\thead{Dominican Republic} & X\,(171) & & X\,(106) & & X\,(89) \\\thead{Ecuador} & & X\,(128) & & X\,(95) & X\,(109) \\\thead{El Salvador} & X\,(166) & X\,(131) & X\,(98) & & \\\thead{Grenada} & & & & & X\,(90) \\\thead{Gutemala} & & X\,(125) & X\,(102) & & \\\thead{Haili} & X\,(130) & X\,(00) & X\,(110) & & X\,(60) \\\thead{Horduras} & & & X\,(117) & X\,(159) & \\\thead{Jamaica} & & X\,(123) & X\,(106) & & X\,(89) \\\thead{Picaragua} & X\,(165) & X\,(109) & X\,(108) & & X\,(135) \\\thead{Panama} & X\,(160) & & X\,(126) & & X\,(135) \\\thead{Peru} & & X\,(106) & & X\,(106) & X\,(95) \\\thead{St\,Kits and Nevis} & & & & & X\,(23) \\\thead{St\,Lucia} & & & & & X\,(60) \\\thead{Trindad and Tobago} & & & & & X\,(104) \\\hline \end{tabular}
# Partnership Themes Listed by Frequency Within and Between Units of Analysis :  \begin{tabular}{|p{3cm}|c|c|c|c|c|c|c|c|c|c|c|}\hline & \multicolumn{2}{c|}{\textbf{\tiny USG}} & \multicolumn{2}{c|}{\textbf{\tiny PN}} & & \multicolumn{2}{c|}{\textbf{\tiny NGO}} & \multicolumn{3}{c|}{\textbf{\tiny between Units of Analysis}} \\\cline{2-5} \cline{7-10}\textbf{\tiny Theme} & \textbf{\tiny Mullary} & \textbf{\tiny Non-Mullary} & \textbf{\tiny Pacific Region} & \textbf{\tiny Non-region Presence} & \textbf{\tiny HN} & \textbf{\tiny Long-term} & \textbf{\tiny Short-term} & \textbf{\tiny Local} & \textbf{\tiny Tactical} & \textbf{\tiny Operational} & \textbf{\tiny Strategic} \\\hline {\tiny Developing relationships} & X & X & X & X & X & X & X & X & X & X \\\hline {\tiny Developing new perspecives} & X & X & X & X & X & X & X & X & X & X \\\hline {\tiny Developing credibility} & X & X & X & X & & X & X & X & X & X \\\hline {\tiny Sharing resources} & X & X & X & X & X & & X & X & X & X & X \\\hline {\tiny Increasing visibility} & X & X & X & X & & X & X & X & X & X \\\hline {\tiny Generating innovation} & X & X & X & X & X & & & X & X & X & X \\\hline {\tiny Achieving Organization Objectives} & & X & & X & X & X & X & X & X & X & X \\\hline {\tiny Developing rust} & X & & X & & X & X & X & X & X & X & X \\\hline {\tiny Increasing HN capacity} & X & X & & X & X & & X & X & X & X & X \\\hline {\tiny Performing new activities} & X & & X & X & & X & & X & X & & \\\hline {\tiny Opening dialogue} & X & X & & X & X & & & X & & X & X \\\hline {\tiny Understanding partner constraints} & X & X & & X & & & X & X & X & X & X \\\hline {\tiny Understanding partner agenda} & X & X & & X & & & & X & & X & X \\\hline {\tiny Understanding HN needs} & X & & & X & & X & X & & X & X & X \\\hline {\tiny Sharing leadership} & & & X & & & X & & & X & X & X \\\hline \end{tabular}
# Documentary Partnership Themes Matching Case Study :  \begin{tabular}{|p{6cm}|>{\centering\arraybackslash}m{3cm}|>{\centering\arraybackslash}m{3cm}|>{\centering\arraybackslash}m{3cm}|}\hline \textbf{\scriptsize Theme} & \textbf{\scriptsize Policy} & \textbf{\scriptsize Guidance} & \textbf{\scriptsize PlanningExecution} \\ \hline \scriptsize Developing relationships & \scriptsize X & \scriptsize X & \scriptsize X \\ \hline \scriptsize Develop new perspecives & \scriptsize X & \scriptsize X & \scriptsize X \\ \hline \scriptsize Sharing resources & \scriptsize X & \scriptsize X & \scriptsize \\ \hline \scriptsize Understanding partner constraints & \scriptsize X & \scriptsize X & \scriptsize \\ \hline \scriptsize Developing credibility & & & \scriptsize X \\ \hline \scriptsize Opening dialogue & \scriptsize X & \scriptsize X & \scriptsize \\ \hline \scriptsize Understand HN needs & \scriptsize X & & \scriptsize \\ \hline \scriptsize Increase HN Capacity & \scriptsize X & \scriptsize X & \scriptsize X \\ \hline \scriptsize Understanding parner agenda & \scriptsize X & \scriptsize X & \scriptsize X \\ \hline \scriptsize Performing new activities & \scriptsize X & \scriptsize X & \scriptsize \\ \hline \scriptsize Developing trust & \scriptsize X & \scriptsize X & \scriptsize X \\ \hline \scriptsize Generating innovation & \scriptsize X & \scriptsize X & \scriptsize X \\ \hline \scriptsize Achieving Organization Objectives & \scriptsize X & \scriptsize X & \scriptsize \\ \hline \scriptsize Increasing visibility & \scriptsize X & \scriptsize X & \scriptsize X \\ \hline \scriptsize Sharing leadership & & \scriptsize X & \scriptsize \\ \hline \end{tabular}
# Recent missions of the USNS Mercy (3) :  begin{tabular}{@{}l@{\hspace{2mm}}l@{\hspace{2mm}}l@{\hspace{2mm}}l@{}}\toprule\textbf{Pacific Partner 2010} & Humanitarian and civic assistance to Vietnam, Cambodia, Indonesia, Timor Lesle, Papua New Guinea, and Palau, Supported by 8 PNs and 17 NGOs, 100,000 + patients treated. \\\textbf{Pacific Partner 2008} & Humanitarian and civic assistance to the Republic of the Philippines, Vietnam, Timo Lesle, Papua New Guinea, and the Federated States of Micronesia, Supported by 10 PNs and several NGOS. \\\textbf{2006 Humanitarian Assistance Mission} & \textbf{\tiny $\bullet$ 90,000$+$ patients treated} \\\textbf{Operation Unified Assistance} & \textbf{\tiny $\bullet$ 19,375 imrunizations administered} \\\textbf{Operation Unified Assistance} & \textbf{\tiny $\bullet$ 1141 pairs of eyeglasses distributed} \\\textbf{Operation Desert Shield/Storm} & \textbf{\tiny $\bullet$ Assisted in the repair of infrastructure and biomedical equipment} \\\textbf{Operation Desert Shield/Storm} & \textbf{\tiny Deployed to the Middle East in support of Operations Desert Shield and Desert Storm.} \\\textbf{Spring 1987 Humanitarian Assistance/ Training Deployment} & \textbf{\tiny $\bullet$ 300 surgeries conducted} \\\textbf{Training Deployment} & \textbf{\tiny Humanitarian assistance to the Republic of the Philippines and other South Pacific islands.} \\\textbf{Operation Desert Shield/Storm} & \textbf{\tiny $\bullet$ 73,000$+$ patients treated} \\\bottomrule\end{tabular}

# %% [markdown]
# Setting up a clean Vector Database and Hybrid search

# %%
'''
user:
db_cf607103ea8262d

password:
Hs1<%^{QRr,2Jc;8

API_KEY:
0a3ae0ae0608129e5e33848199bd46ea36c44d150106e446100a61d69b1813991815e17eb96eee35cba3ff49c759274aecc1e9ba

public_endpoint:
https://in03-cf607103ea8262d.serverless.gcp-us-west1.cloud.zilliz.com

cluster_ID:
in03-cf607103ea8262d

cloud_Region:
gcp-us-west1
'''
# Out:
# '\nuser:\ndb_cf607103ea8262d\n\npassword:\nHs1<%^{QRr,2Jc;8\n\nAPI_KEY:\n0a3ae0ae0608129e5e33848199bd46ea36c44d150106e446100a61d69b1813991815e17eb96eee35cba3ff49c759274aecc1e9ba\n\npublic_endpoint:\nhttps://in03-cf607103ea8262d.serverless.gcp-us-west1.cloud.zilliz.com\n\ncluster_ID:\nin03-cf607103ea8262d\n\ncloud_Region:\ngcp-us-west1\n'

# %%
# !pip3 install --upgrade pip
# Install pymilvus compatible with Milvus v2.3.x
# !pip install pymilvus==2.3.7

# Install pymilvus compatible with Milvus v2.4.x
# !pip install pymilvus==2.4.4

# Update PyMilvus to the newest version
# !pip install --upgrade pymilvus

# Verify installation success
# !pip list | grep pymilvus

#for embeddings
# !pip install FlagEmbedding
# !pip install peft
# Out:
# Requirement already satisfied: pip in /usr/local/lib/python3.10/dist-packages (24.3.1)
# Collecting pymilvus==2.3.7
#   Using cached pymilvus-2.3.7-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: setuptools>=67 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.3.7) (75.1.0)
# Requirement already satisfied: grpcio<=1.60.0,>=1.49.1 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.3.7) (1.60.0)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.3.7) (3.20.3)
# Requirement already satisfied: environs<=9.5.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.3.7) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.3.7) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.3.7) (2.2.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.3.7) (2.32.3)
# Requirement already satisfied: minio>=7.0.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.3.7) (7.2.10)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.3.7) (17.0.0)
# Requirement already satisfied: azure-storage-blob in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.3.7) (12.23.1)
# Requirement already satisfied: marshmallow>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from environs<=9.5.0->pymilvus==2.3.7) (3.23.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from environs<=9.5.0->pymilvus==2.3.7) (1.0.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from minio>=7.0.0->pymilvus==2.3.7) (2024.8.30)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from minio>=7.0.0->pymilvus==2.3.7) (2.2.3)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from minio>=7.0.0->pymilvus==2.3.7) (23.1.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.10/dist-packages (from minio>=7.0.0->pymilvus==2.3.7) (3.21.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from minio>=7.0.0->pymilvus==2.3.7) (4.12.2)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus==2.3.7) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus==2.3.7) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus==2.3.7) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus==2.3.7) (2024.2)
# Requirement already satisfied: azure-core>=1.30.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob->pymilvus==2.3.7) (1.32.0)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob->pymilvus==2.3.7) (43.0.3)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob->pymilvus==2.3.7) (0.7.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->pymilvus==2.3.7) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->pymilvus==2.3.7) (3.10)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core>=1.30.0->azure-storage-blob->pymilvus==2.3.7) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob->pymilvus==2.3.7) (1.17.1)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow>=3.0.0->environs<=9.5.0->pymilvus==2.3.7) (24.1)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->minio>=7.0.0->pymilvus==2.3.7) (21.2.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob->pymilvus==2.3.7) (2.22)
# Using cached pymilvus-2.3.7-py3-none-any.whl (179 kB)
# Installing collected packages: pymilvus
#   Attempting uninstall: pymilvus
#     Found existing installation: pymilvus 2.4.9
#     Uninstalling pymilvus-2.4.9:
#       Successfully uninstalled pymilvus-2.4.9
# Successfully installed pymilvus-2.3.7
# Collecting pymilvus==2.4.4
#   Using cached pymilvus-2.4.4-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: setuptools>=67 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.4.4) (75.1.0)
# Requirement already satisfied: grpcio<=1.63.0,>=1.49.1 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.4.4) (1.60.0)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.4.4) (3.20.3)
# Requirement already satisfied: environs<=9.5.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.4.4) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.4.4) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.4.4) (2.2.2)
# Requirement already satisfied: milvus-lite<2.5.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus==2.4.4) (2.4.10)
# Requirement already satisfied: marshmallow>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from environs<=9.5.0->pymilvus==2.4.4) (3.23.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from environs<=9.5.0->pymilvus==2.4.4) (1.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from milvus-lite<2.5.0,>=2.4.0->pymilvus==2.4.4) (4.66.6)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus==2.4.4) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus==2.4.4) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus==2.4.4) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus==2.4.4) (2024.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow>=3.0.0->environs<=9.5.0->pymilvus==2.4.4) (24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus==2.4.4) (1.16.0)
# Using cached pymilvus-2.4.4-py3-none-any.whl (196 kB)
# Installing collected packages: pymilvus
#   Attempting uninstall: pymilvus
#     Found existing installation: pymilvus 2.3.7
#     Uninstalling pymilvus-2.3.7:
#       Successfully uninstalled pymilvus-2.3.7
# Successfully installed pymilvus-2.4.4
# Requirement already satisfied: pymilvus in /usr/local/lib/python3.10/dist-packages (2.4.4)
# Collecting pymilvus
#   Using cached pymilvus-2.4.9-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: setuptools>69 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (75.1.0)
# Requirement already satisfied: grpcio>=1.49.1 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (1.60.0)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (3.20.3)
# Requirement already satisfied: environs<=9.5.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (2.2.2)
# Requirement already satisfied: milvus-lite<2.5.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (2.4.10)
# Requirement already satisfied: marshmallow>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from environs<=9.5.0->pymilvus) (3.23.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from environs<=9.5.0->pymilvus) (1.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from milvus-lite<2.5.0,>=2.4.0->pymilvus) (4.66.6)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (2024.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow>=3.0.0->environs<=9.5.0->pymilvus) (24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.16.0)
# Using cached pymilvus-2.4.9-py3-none-any.whl (201 kB)
# Installing collected packages: pymilvus
#   Attempting uninstall: pymilvus
#     Found existing installation: pymilvus 2.4.4
#     Uninstalling pymilvus-2.4.4:
#       Successfully uninstalled pymilvus-2.4.4
# Successfully installed pymilvus-2.4.9
# pymilvus                           2.4.9
# Requirement already satisfied: FlagEmbedding in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from FlagEmbedding) (2.5.0+cu121)
# Requirement already satisfied: transformers==4.44.2 in /usr/local/lib/python3.10/dist-packages (from FlagEmbedding) (4.44.2)
# Requirement already satisfied: datasets==2.19.0 in /usr/local/lib/python3.10/dist-packages (from FlagEmbedding) (2.19.0)
# Requirement already satisfied: accelerate>=0.20.1 in /usr/local/lib/python3.10/dist-packages (from FlagEmbedding) (0.34.2)
# Requirement already satisfied: sentence-transformers in /usr/local/lib/python3.10/dist-packages (from FlagEmbedding) (3.2.1)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (from FlagEmbedding) (0.13.2)
# Requirement already satisfied: ir-datasets in /usr/local/lib/python3.10/dist-packages (from FlagEmbedding) (0.5.8)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.10/dist-packages (from FlagEmbedding) (0.2.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.10/dist-packages (from FlagEmbedding) (3.20.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (3.16.1)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (17.0.0)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (2.2.2)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (4.66.6)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (3.5.0)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (0.70.16)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets==2.19.0->FlagEmbedding) (2024.3.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (3.10.10)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (0.24.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets==2.19.0->FlagEmbedding) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers==4.44.2->FlagEmbedding) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers==4.44.2->FlagEmbedding) (0.4.5)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers==4.44.2->FlagEmbedding) (0.19.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate>=0.20.1->FlagEmbedding) (5.9.5)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->FlagEmbedding) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->FlagEmbedding) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->FlagEmbedding) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->FlagEmbedding) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.6.0->FlagEmbedding) (1.3.0)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->FlagEmbedding) (4.12.3)
# Requirement already satisfied: inscriptis>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->FlagEmbedding) (2.5.0)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->FlagEmbedding) (5.3.0)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->FlagEmbedding) (2.6)
# Requirement already satisfied: lz4>=3.1.10 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->FlagEmbedding) (4.3.3)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->FlagEmbedding) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->FlagEmbedding) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->FlagEmbedding) (0.1.9)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->FlagEmbedding) (3.3.0)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from ir-datasets->FlagEmbedding) (0.2.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->FlagEmbedding) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->FlagEmbedding) (1.13.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers->FlagEmbedding) (10.4.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets->FlagEmbedding) (2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0->FlagEmbedding) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0->FlagEmbedding) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0->FlagEmbedding) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0->FlagEmbedding) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0->FlagEmbedding) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0->FlagEmbedding) (1.17.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets==2.19.0->FlagEmbedding) (4.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.19.0->FlagEmbedding) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.19.0->FlagEmbedding) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.19.0->FlagEmbedding) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets==2.19.0->FlagEmbedding) (2024.8.30)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from trec-car-tools>=2.5.4->ir-datasets->FlagEmbedding) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->FlagEmbedding) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.19.0->FlagEmbedding) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.19.0->FlagEmbedding) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets==2.19.0->FlagEmbedding) (2024.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers->FlagEmbedding) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers->FlagEmbedding) (3.5.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets==2.19.0->FlagEmbedding) (1.16.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.12.0->aiohttp->datasets==2.19.0->FlagEmbedding) (0.2.0)
# Requirement already satisfied: peft in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from peft) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from peft) (24.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from peft) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from peft) (6.0.2)
# Requirement already satisfied: torch>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from peft) (2.5.0+cu121)
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (from peft) (4.44.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from peft) (4.66.6)
# Requirement already satisfied: accelerate>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from peft) (0.34.2)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from peft) (0.4.5)
# Requirement already satisfied: huggingface-hub>=0.17.0 in /usr/local/lib/python3.10/dist-packages (from peft) (0.24.7)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (2024.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.17.0->peft) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13.0->peft) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.13.0->peft) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (2024.9.11)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers->peft) (0.19.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.13.0->peft) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.17.0->peft) (2024.8.30)

# %%
import time
time.sleep(5)
# !pip install pymilvus
import pymilvus
from pymilvus import MilvusClient, AnnSearchRequest, WeightedRanker
# Out:
# Requirement already satisfied: pymilvus in /usr/local/lib/python3.10/dist-packages (2.4.9)
# Requirement already satisfied: setuptools>69 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (75.1.0)
# Requirement already satisfied: grpcio>=1.49.1 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (1.60.0)
# Requirement already satisfied: protobuf>=3.20.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (3.20.3)
# Requirement already satisfied: environs<=9.5.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (9.5.0)
# Requirement already satisfied: ujson>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (5.10.0)
# Requirement already satisfied: pandas>=1.2.4 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (2.2.2)
# Requirement already satisfied: milvus-lite<2.5.0,>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from pymilvus) (2.4.10)
# Requirement already satisfied: marshmallow>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from environs<=9.5.0->pymilvus) (3.23.0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.10/dist-packages (from environs<=9.5.0->pymilvus) (1.0.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from milvus-lite<2.5.0,>=2.4.0->pymilvus) (4.66.6)
# Requirement already satisfied: numpy>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.4->pymilvus) (2024.2)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.10/dist-packages (from marshmallow>=3.0.0->environs<=9.5.0->pymilvus) (24.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.2.4->pymilvus) (1.16.0)

# %%
"""
RUN THIS CODE AGAIN IF IT FAILS THE FIRST TIME!!!
RUN THIS CODE AGAIN IF IT FAILS THE FIRST TIME!!!
RUN THIS CODE AGAIN IF IT FAILS THE FIRST TIME!!!
RUN THIS CODE AGAIN IF IT FAILS THE FIRST TIME!!!
RUN THIS CODE AGAIN IF IT FAILS THE FIRST TIME!!!


Also takes about 7 minutes to run if embedding as not stored to your google drive if it is than it would take 30 seconds
"""





import random
import numpy as np
import os
import pickle

from transformers import AutoTokenizer, AutoModel
import torch

# Load model and tokenizer from Hugging Face Hub
tokenizer = AutoTokenizer.from_pretrained('BAAI/llm-embedder')
model = AutoModel.from_pretrained('BAAI/llm-embedder')
model.eval()





# Step 1: Replace these with your actual endpoint and token
CLUSTER_ENDPOINT = "https://in03-cf607103ea8262d.serverless.gcp-us-west1.cloud.zilliz.com"
TOKEN = "0a3ae0ae0608129e5e33848199bd46ea36c44d150106e446100a61d69b1813991815e17eb96eee35cba3ff49c759274aecc1e9ba"

# Step 2: Connect to your Milvus cluster hosted on Zilliz Cloud
client = MilvusClient(
    uri=CLUSTER_ENDPOINT,
    token=TOKEN
)

"""

EMBEDDING MODEL, turning CHUNKS INTO EMBEDDINGS

"""



keys = combined_chunk_list
# Step 6: Generate embeddings for the chunks (keys)

# Define the save path in your Google Drive
save_path = '/content/drive/MyDrive/Oct_31_embeddings_data.pkl'

# Check if the embeddings file exists if it does just load it up if not convert chuncks to embeddings
if os.path.exists(save_path):
    # Load embeddings, keys, and metadata_list from the file
    with open(save_path, 'rb') as f:
        data = pickle.load(f)
        sentence_embeddings = data['embeddings']
        keys = data['keys']
        metadata_list = data['metadata_list']
    print("Loaded embeddings, keys, and metadata from Google Drive.")
else:

    # Tokenize sentences
    encoded_input = tokenizer(keys, padding=True, truncation=True, return_tensors='pt')

    # Compute embeddings
    with torch.no_grad():
        model_output = model(**encoded_input)
        # Use CLS token embedding as sentence embedding
        sentence_embeddings = model_output[0][:, 0]
        # Normalize embeddings for cosine similarity
        sentence_embeddings = torch.nn.functional.normalize(sentence_embeddings, p=2, dim=1)

    print("Generated embeddings.")

    # Save embeddings, keys, and metadata_list to Google Drive
    with open(save_path, 'wb') as f:
        pickle.dump({'embeddings': sentence_embeddings, 'keys': keys, 'metadata_list': metadata_list}, f)
    print("Saved embeddings, keys, and metadata to Google Drive.")
# Out:
# DEBUG:pymilvus.milvus_client.milvus_client:Created new connection using: 1f323cdbb22d4dc88b6c82aa964d04bb
# Loaded embeddings, keys, and metadata from Google Drive.

# %%
from pymilvus import connections, Collection, FieldSchema, CollectionSchema, DataType, AnnSearchRequest, WeightedRanker
import random
import time

# Connect to your Zilliz Cloud cluster
CLUSTER_ENDPOINT = "https://in03-cf607103ea8262d.serverless.gcp-us-west1.cloud.zilliz.com"
TOKEN = "0a3ae0ae0608129e5e33848199bd46ea36c44d150106e446100a61d69b1813991815e17eb96eee35cba3ff49c759274aecc1e9ba"

# Step 1: Connect to the cluster
connections.connect(uri=CLUSTER_ENDPOINT, token=TOKEN)

# Step 2: Create the collection schema with 'metadata' field
def create_collection():
    # Define field schemas
    fields = [
        FieldSchema(name="id", dtype=DataType.INT64, is_primary=True, auto_id=False),
        FieldSchema(name="posterVector", dtype=DataType.FLOAT_VECTOR, dim=768),  # Only poster vector remains
        FieldSchema(name="metadata", dtype=DataType.JSON),  # Metadata as JSON
        FieldSchema(name="chunks", dtype=DataType.JSON)  # Store chunks as JSON, containing a list of strings

    ]

    # Create the collection schema
    schema = CollectionSchema(fields=fields, enable_dynamic_field=False)

    # Create the collection
    collection = Collection(name="Oct_31", schema=schema)
    print("Collection 'Oct_31' created successfully.")
    return collection


# Step 4: Create index for vector fields
def create_index(collection):
    # Define the index parameters
    index_params = {
        "metric_type": "L2",  # L2 distance for similarity search
        "index_type": "AUTOINDEX"
    }

    # Create an index for the 'posterVector' field
    collection.create_index("posterVector", index_params)
    print("Index created for 'posterVector'.")



# Step 5: Insert vector embeddings into the collection (with 'metadata' field)
def insert_embeddings(collection, k_embeddings, m_data_list, c_list):
    # Check the dimension of the embeddings being inserted
    print(f"Inserting embeddings with dimensions: {len(k_embeddings[0])}")

    data = [
        {"id": i, "posterVector": k_embeddings[i], "metadata": m_data_list[i], "chunks": c_list[i]}
        for i in range(len(k_embeddings))
    ]

    # Insert the data into the collection
    collection.insert(data)
    print(f"Inserted {len(data)} entities into the collection 'Oct_31'")


# Step 7: Execute the full workflow
collection = create_collection()  # Create the collection with schema
create_index(collection)  # Create indexes for vector fields
time.sleep(5)  # Allow time for index creation
insert_embeddings(collection,sentence_embeddings, metadata_list, combined_chunk_list)  # Insert embeddings into the collection
time.sleep(5)  # Allow time for data to be indexed
# Out:
# Collection 'Oct_31' created successfully.
# Index created for 'posterVector'.
# Inserting embeddings with dimensions: 768
# Inserted 87 entities into the collection 'Oct_31'
